# %% [markdown]
# # Homework 2 : 單光子電腦斷層掃描的多類別分類
# 在這份作業中，請各位將 TODO 填寫好。
#
# 1. 調整適當的參數。
# 2. 將 validation 空白處填起來讓程式能夠運作
# 3. 寫出當 mode = valid、test 的 getitem()。
# 4. split the training dataset。
# 5. 調整適當的 optimizer、scheduler，雖然不一定會比較好，但可以嘗試看看。
# 6. 畫出 train 跟 valid 的 Misclassification Rate 圖。
# 7. 用相似的手法建立 Resnet, VIT model 架構。
# 8. 在 testing 裡填空格。
# 9. 填寫 test_dataset、test_loader、model 三個空格。
# 10. 挑選你認為最好的 model 並將預測結果輸出在 submission.csv。

# %% [markdown]
# kaggle rule:
# 1. 不得使用兩隻以上的帳號繳交 submission檔案 (可參加但不可丟答案)
# 2. team的名稱記得一定要改成學號

# %% [markdown]
# ## Import Packages

# %%
# torchsummary 可以讓模型視覺化，以及匯出模型每層的詳細數量和每層的比例。
# !pip install torchsummary
# Out:
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl.metadata (296 bytes)
# Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1

# %%
import pydicom
import pandas as pd
import numpy as np
import os
import random

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import Dataset, Subset, DataLoader
from torchvision.transforms import v2
import torchvision.models as models # VGG16, ResNet50
from torchsummary import summary # summary for models

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score


import warnings
warnings.filterwarnings("ignore", category = FutureWarning)

# %% [markdown]
# ## Configuration

# %%
# TODO_1: 調整適當的參數(除了 num_classes，你可以任意調整以下的超參數)

class config:
    
    root = "/kaggle/input/2024dl"
    batch_size = 16
    lr = 1e-4
    epochs = 100
    weight_decay = 1e-3
    seed = 42
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    num_classes = 3
    
print('device:', config.device)
# Out:
# device: cuda

# %% [markdown]
# ## Input Data

# %%
train_data = pd.read_csv(os.path.join(config.root, 'train.csv'))
test_data = pd.read_csv(os.path.join(config.root, 'test.csv'))

print(f'Number of training samples: {train_data.shape[0]}')
print(f'Number of testing samples: {test_data.shape[0]}')
# Out:
# Number of training samples: 161
# Number of testing samples: 41

# %%
train_data['Stage'].value_counts().sort_index()
# Out:
# Stage
# 1    44
# 2    42
# 3    75
# Name: count, dtype: int64

# %% [markdown]
# ## Defined functions

# %%
def seed_everything(seed):
    # Set Python random seed
    random.seed(seed)
    
    # Set NumPy random seed
    np.random.seed(seed)
    
    # Set PyTorch random seed for CPU and GPU
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    
    # Set PyTorch deterministic operations for cudnn backend
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


def evaluator(preds, gts):
    preds = preds.cpu().numpy() if isinstance(preds, torch.Tensor) else preds
    gts = gts.cpu().numpy() if isinstance(gts, torch.Tensor) else gts
    acc = accuracy_score(preds, gts)
    f1 = f1_score(preds, gts, average = "macro")
    misclassification_rate = 1 - acc
    
    return acc, f1, misclassification_rate

def train_one_epoch(model, train_loader, optimizer, scheduler, criterion, device):
    # 作用是啟用 batch normalization 和 dropout。
    # 保證 BN 層能夠用到每個 batch 資料的平均值和變異數。對於 Dropout 是隨機取一部分網路連線來訓練更新參數。
    model.train() 
    
    train_loss = .0
    predictions, ground_truths = [], []
    
    for images, ages, genders, labels in train_loader:
        images = images.to(device = device, dtype = torch.float)
        ages = ages.to(device = device, dtype = torch.float)
        genders = genders.to(device = device, dtype = torch.float)
        labels = labels.to(device = device, dtype = torch.long)

        optimizer.zero_grad()
        logits = model(images, ages, genders)
        
        # Pytorch 中的分類損失函數（如 CrossEntropyLoss）期望 label 為 0 開始的整數。
        labels = torch.sub(labels, 1) # labels 1, 2, 3 -> 0, 1, 2
        loss = criterion(logits, labels)
        loss.backward()

        optimizer.step()

        train_loss += loss.item()
        preds = torch.argmax(logits, dim = 1)

        predictions.append(preds)
        ground_truths.append(labels)
    
    scheduler.step()

    train_loss /= len(train_loader)

    predictions = torch.cat(predictions)
    ground_truths = torch.cat(ground_truths)
    train_acc, train_f1, train_misclass = evaluator(predictions, ground_truths)

    return train_loss, 100*train_acc, 100*train_f1, 100*train_misclass


def validation(model, valid_loader, criterion, device):
    # 確保 BN 層能夠用全部訓練資料的平均值和變異數，即驗證過程中要保證 BN 層的平均值和變異數不變。對於 Dropout 是利用了所有網路連接，即不進行隨機捨棄神經元。
    # pytorch 會自動把 BN 和 DropOut 固定住，不會取平均，而是用訓練好的數值。
    model.eval()
    valid_loss = .0
    predictions, ground_truths = [], []

    # TODO_2: 請將空白處填起來讓程式能夠運作。

    # 這邊禁用 PyTorch 梯度的自動計算，因為在 validation 階段我們不需要更新 model 的權重，因此不需要進行反向傳播(backpropagation)和梯度計算。
    with torch.no_grad():
        for images, ages, genders, labels in valid_loader:
            images = 
            ages = 
            genders = 
            labels = 

            logits = 
            labels = 
            loss = 

            valid_loss += 
            preds = 

            predictions.append(preds)
            ground_truths.append(labels)

        valid_loss /= 

        predictions = 
        ground_truths = 
        
        valid_acc, valid_f1, valid_misclass = 
        
    return valid_loss, 100*valid_acc, 100*valid_f1, 100*valid_misclass

# %% [markdown]
# ## Transformation

# %%
class Normalization(object):
    
    def __call__(self, image): # 定義有image之後要進行的資料處理
        changed_image = (image - image.min())/(image.max() - image.min())
        return changed_image

def build_transform(is_train):
    """
    Create a data transformation pipeline for image preprocessing in deep learning tasks.
    """
    t = []
    if is_train:
        # 若是包含 Random 系列的圖像增強，則只能加在train裡面
        t.append(v2.CenterCrop(size = (50, 50)))
        t.append(Normalization())
        return v2.Compose(t)
    
    t.append(v2.CenterCrop(size = (50, 50)))
    t.append(Normalization())
    return v2.Compose(t)

# %% [markdown]
# ## Defined Dataset

# %%
class ParkinsonsDataset(torch.utils.data.Dataset):

    def __init__(self, df, mode = None, transforms = None): # 將所有資料提出
        self.df = df
        self.mode = mode
        self.transforms = transforms
        
    def __len__(self):
        return self.df.shape[0]

    def __getitem__(self, x): # 找出指定的資料
        
        age = torch.tensor(self.df.iloc[x, 1]) # 年齡
        gender = torch.tensor(self.df.iloc[x, 2]) # 性別
        index = torch.tensor(self.df.iloc[x, 4]) # 起始張數
        
        # 影像前處理
        image = pydicom.dcmread(config.root + self.df.iloc[x, 3]).pixel_array
        image = torch.tensor(image.astype(np.float32))
        image = image[index-1:index+2, :, :]
        
        if self.mode == "train":
            label = torch.tensor(self.df.iloc[x, 5]) # 標籤
            if self.transforms: image = self.transforms(image)

            return image, age, gender, label
        
        
        # TODO_3: 寫出當 mode = valid、test 的 getitem()
        
        
        elif self.mode == "valid":
            

            return image, age, gender, label
    
        elif self.mode == "test":
            

            return image, age, gender

# %% [markdown]
# ## Redefined VGG16

# %% [markdown]
# ![image.png](attachment:2c75a377-2bb4-46bf-b07b-1abe6fd69ce8.png)

# %%
# VGG: Visual Geometry Group Network (視覺幾何群網絡)
# VGG16 的緣由: VGG 結構中有 13 個卷積層和 3 個全連接層

class VGGplus(nn.Module):
    def __init__(self, num_classes, input_size = (3, 50, 50), features_grad = False): # 默認輸出為分到每一類的機率
        super().__init__()
        
        # 取出 vgg16 中的特徵層
        vgg16 = models.vgg16(weights = 'IMAGENET1K_V1', progress = True) # progress = True：顯示下載進度條。
        
        # nn.Identity() 是 Pytorch 中的特殊層，不會改變輸入，只是作為佔位符。這樣你以方便修改模型結構而不會影響其整體的輸出 size
        vgg16.features[30] = nn.Identity()
        
        # 將 VGG16 的輸出特徵圖壓縮 1x1，可以得到一個 512 維的特徵向量，便於與後面的 Fully Connected Layer 結合並處理輸入的不同尺寸的圖像。
        vgg16.avgpool = nn.AdaptiveAvgPool2d(1)
        
        # 移除 VGG16 預設的分類器
        vgg16.classifier = nn.Identity()
        
        # 固定/不固定特徵層的參數值: False/True
        # features_grad: 控制是否對 VGG16 的特徵提取層進行微調(參與梯度計算)
        # 因為資料量不大，因此將 param.requires_grad 設為 False，只訓練新的分類層，減少訓練時間和 overfitting 風險。
        for param in vgg16.features.parameters():
            param.requires_grad = features_grad
        self.backend = vgg16
         
        # 增加分類層
        self.classifier = nn.Sequential(
          nn.Linear(512 + 2, num_classes) # 512: vgg16 特徵層結果, 2: age & gender
        )

    def forward(self, x, age, gender):
        output = self.backend(x)
        outputs = torch.cat([output, age.view(-1, 1), gender.view(-1, 1)], dim = 1) # output size = (batch_size, 512), age size = (batch_size), age.view(-1, 1) size = (batch_size, 1), dim = 1; columns concat
        outputs = self.classifier(outputs) # outputs size = (batch_size, 3), 3: labels
        return outputs

# %%
model = VGGplus(num_classes = 3)
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 197MB/s]
# VGGplus(
#   (backend): VGG(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace=True)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU(inplace=True)
#       (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU(inplace=True)
#       (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (20): ReLU(inplace=True)
#       (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU(inplace=True)
#       (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (25): ReLU(inplace=True)
#       (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (27): ReLU(inplace=True)
#       (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (29): ReLU(inplace=True)
#       (30): Identity()
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=1)
#     (classifier): Identity()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=514, out_features=3, bias=True)
#   )
# )

# %%
total_params = sum(p.numel() for p in model.parameters())
print("總參數量:", total_params)
del model
# Out:
# 總參數量: 14716233

# %% [markdown]
# ## VGG16 Architecture Overview and Internal Functions

# %% [markdown]
# ### 1. 導入 vgg16 的架構和 ImageNet 訓練出來的權重 (**transfer learning**)

# %%
vgg16 = models.vgg16(weights = 'IMAGENET1K_V1', progress = True)
print(vgg16)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
total_params = sum(p.numel() for p in vgg16.parameters())
print("總參數量:", total_params)
# Out:
# 總參數量: 138357544

# %% [markdown]
# 以下簡單介紹 vgg16 中使用到的函式: (以下函式的輸入都需要四個維度: (N = number of data, C = number of channels, H = Height, W = Width))

# %% [markdown]
# > [Conv2d](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html)(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#
# > * 3: in_channels
# > * 64: out_channels
# > * stride = (1, 1): kernel 的移動由左至右，由上至下，步長皆為1
# > * padding = (1, 1): 在輸入的周圍填充一層0
#
# > Note:
# > * 雖然是 2d 的 convolution，但實際的輸入是和 kernel 都是 3 維陣列，而 2d 指的是 kernel 移動的方向。
# > * 因為 1 個 (3, 3, 3) 的 kernel 和 1 個 bias 遍歷一次輸入就會產生一層輸出，這邊的輸出有64層，就需要 64 個 (3, 3, 3) 的 kernal 和對應的 64 個 bias。
# > * 這樣的 stride 和 padding 的設定可以讓輸出和輸入的長寬不變。

# %% [markdown]
# ![](https://discuss.pytorch.org/uploads/default/original/3X/6/0/60994f2ed1f8c34ee6e83741e2e87fca0a1b4655.jpeg)

# %% [markdown]
# ![image.png](attachment:ee9a3011-5f3f-4f86-9d1f-85c62afa3778.png)

# %% [markdown]
# 簡易算法:
# 1. 使用 **kernel_size**: H - kernel_size + 1
# 2. 使用 **kernel_size, stride**: (H - kernel_size) / stride + 1
# 3. 使用 **kernel_size, stride, padding**: (H + (2 * padding) - kernel_size) / stride + 1
# 4. 使用 **kernel_size, stride, padding, dilation**: (H + (2 * padding) - dilation * (kernel_size - 1) - 1) / stride + 1

# %%
m = nn.Conv2d(3, 64, kernel_size = (3, 3), stride = (1, 1), padding = (1, 1))
print('2D convolutional layer: ', m, '\n')

input = torch.randn(1, 3, 50, 50)
print('input shape: ', input.shape)

output = m(input)
print('output shape: ', output.shape, '\n')


for i, param in enumerate(m.parameters()):
    if i == 0:
        print('weights: ', param.shape)
    else:
        print('bias: ', param.shape)

del m, input, output
# Out:
# 2D convolutional layer:  Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#
# input shape:  torch.Size([1, 3, 50, 50])
# output shape:  torch.Size([1, 64, 50, 50])
#
# weights:  torch.Size([64, 3, 3, 3])
# bias:  torch.Size([64])

# %% [markdown]
# > [MaxPool2d](https://pytorch.org/docs/stable/generated/torch.nn.MaxPool2d.html#torch.nn.MaxPool2d)(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#
# > * ceil_mode: True = 將不足的邊用 NAN 補齊，False = 將不足的邊直接刪除

# %%
input = torch.tensor([[1, 1, 1], [2, 2, 2], [3, 3, 3]]).reshape(1, 1, 3, 3).float()
print(input)

print("\nceil_mode = False")
m1 = nn.MaxPool2d(2, stride = 2, ceil_mode = False)
output1 = m1(input)
print(output1)

print("\nceil_mode = True")
m2 = nn.MaxPool2d(2, stride = 2, ceil_mode = True)
output2 = m2(input)
print(output2)

del m1, m2, input, output1, output2
# Out:
# tensor([[[[1., 1., 1.],
#           [2., 2., 2.],
#           [3., 3., 3.]]]])
#
# ceil_mode = False
# tensor([[[[2.]]]])
#
# ceil_mode = True
# tensor([[[[2., 2.],
#           [3., 3.]]]])

# %% [markdown]
# > [AdaptiveAvgPool2d](https://pytorch.org/docs/stable/generated/torch.nn.AdaptiveAvgPool2d.html)(output_size=(7, 7))
#
# > 按照期望的輸出大小對輸入做平均

# %%
input = torch.tensor([[1, 1, 1], [2, 2, 2], [3, 3, 3]]).reshape(1, 1, 3, 3).float()
print(input, '\n')

m7 = nn.AdaptiveAvgPool2d(output_size = (7, 7))
output = m7(input)
print(output, '\n')

m1 = nn.AdaptiveAvgPool2d(output_size = (1, 1))
output = m1(input)
print(output)

del input, m7, m1, output
# Out:
# tensor([[[[1., 1., 1.],
#           [2., 2., 2.],
#           [3., 3., 3.]]]])
#
# tensor([[[[1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000],
#           [1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000],
#           [1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000, 1.5000],
#           [2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000],
#           [2.5000, 2.5000, 2.5000, 2.5000, 2.5000, 2.5000, 2.5000],
#           [3.0000, 3.0000, 3.0000, 3.0000, 3.0000, 3.0000, 3.0000],
#           [3.0000, 3.0000, 3.0000, 3.0000, 3.0000, 3.0000, 3.0000]]]])
#
# tensor([[[[2.]]]])

# %% [markdown]
# 雖然 AdaptiveAvgPool2d() 的輸出大小可以大於輸入大小，但這種作法可能導致訊息的丟失。

# %% [markdown]
# ### 2. 觀察 vgg16 的 Output Shape 去設計 feature layers 和 classifier layers 之間的連接層

# %%
# 因 summary() 的 input 存在GPU中, 要將 model 也移至 GPU 上才能運行
vgg16.to(config.device)
summary(vgg16, input_size = (3, 50, 50))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 50, 50]           1,792
#               ReLU-2           [-1, 64, 50, 50]               0
#             Conv2d-3           [-1, 64, 50, 50]          36,928
#               ReLU-4           [-1, 64, 50, 50]               0
#          MaxPool2d-5           [-1, 64, 25, 25]               0
#             Conv2d-6          [-1, 128, 25, 25]          73,856
#               ReLU-7          [-1, 128, 25, 25]               0
#             Conv2d-8          [-1, 128, 25, 25]         147,584
#               ReLU-9          [-1, 128, 25, 25]               0
#         MaxPool2d-10          [-1, 128, 12, 12]               0
#            Conv2d-11          [-1, 256, 12, 12]         295,168
#              ReLU-12          [-1, 256, 12, 12]               0
#            Conv2d-13          [-1, 256, 12, 12]         590,080
#              ReLU-14          [-1, 256, 12, 12]               0
#            Conv2d-15          [-1, 256, 12, 12]         590,080
#              ReLU-16          [-1, 256, 12, 12]               0
#         MaxPool2d-17            [-1, 256, 6, 6]               0
#            Conv2d-18            [-1, 512, 6, 6]       1,180,160
#              ReLU-19            [-1, 512, 6, 6]               0
#            Conv2d-20            [-1, 512, 6, 6]       2,359,808
#              ReLU-21            [-1, 512, 6, 6]               0
#            Conv2d-22            [-1, 512, 6, 6]       2,359,808
#              ReLU-23            [-1, 512, 6, 6]               0
#         MaxPool2d-24            [-1, 512, 3, 3]               0
#            Conv2d-25            [-1, 512, 3, 3]       2,359,808
#              ReLU-26            [-1, 512, 3, 3]               0
#            Conv2d-27            [-1, 512, 3, 3]       2,359,808
#              ReLU-28            [-1, 512, 3, 3]               0
#            Conv2d-29            [-1, 512, 3, 3]       2,359,808
#              ReLU-30            [-1, 512, 3, 3]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 7, 7]               0
#            Linear-33                 [-1, 4096]     102,764,544
#              ReLU-34                 [-1, 4096]               0
#           Dropout-35                 [-1, 4096]               0
#            Linear-36                 [-1, 4096]      16,781,312
#              ReLU-37                 [-1, 4096]               0
#           Dropout-38                 [-1, 4096]               0
#            Linear-39                 [-1, 1000]       4,097,000
# ================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 11.01
# Params size (MB): 527.79
# Estimated Total Size (MB): 538.83
# ----------------------------------------------------------------

# %% [markdown]
# 參數數量 = (Input features) × (Output features) + (Bias terms)
# Input features = 25,088 = 512×7×7, Output features = 4,096, Bias terms = 4,096
# 所以，參數數量 = 25,088 × 4,096 + 4,096 = 102,760,192 + 4,096 = 102,764,288
# 以上顯示的 102,764,544，比我們的計算多了 256 個參數。可能來自於 input features 數量的誤差，而這種誤差可能是由於不同的張量操作（如 padding、四捨五入）所引起的。

# %% [markdown]
# 在 ReLU-30 得到的輸出大小已經是 (512, 3, 3)，如果使用模型中的 MaxPool2d-31: MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, **ceil_mode=False**)，會有些資訊被忽略，所以接下來會更改 31 層和 32 層。

# %%
vgg16.features[30] = nn.Identity()
vgg16.avgpool = nn.AdaptiveAvgPool2d(1)
vgg16.classifier = nn.Identity()
summary(vgg16, (3, 50, 50))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 50, 50]           1,792
#               ReLU-2           [-1, 64, 50, 50]               0
#             Conv2d-3           [-1, 64, 50, 50]          36,928
#               ReLU-4           [-1, 64, 50, 50]               0
#          MaxPool2d-5           [-1, 64, 25, 25]               0
#             Conv2d-6          [-1, 128, 25, 25]          73,856
#               ReLU-7          [-1, 128, 25, 25]               0
#             Conv2d-8          [-1, 128, 25, 25]         147,584
#               ReLU-9          [-1, 128, 25, 25]               0
#         MaxPool2d-10          [-1, 128, 12, 12]               0
#            Conv2d-11          [-1, 256, 12, 12]         295,168
#              ReLU-12          [-1, 256, 12, 12]               0
#            Conv2d-13          [-1, 256, 12, 12]         590,080
#              ReLU-14          [-1, 256, 12, 12]               0
#            Conv2d-15          [-1, 256, 12, 12]         590,080
#              ReLU-16          [-1, 256, 12, 12]               0
#         MaxPool2d-17            [-1, 256, 6, 6]               0
#            Conv2d-18            [-1, 512, 6, 6]       1,180,160
#              ReLU-19            [-1, 512, 6, 6]               0
#            Conv2d-20            [-1, 512, 6, 6]       2,359,808
#              ReLU-21            [-1, 512, 6, 6]               0
#            Conv2d-22            [-1, 512, 6, 6]       2,359,808
#              ReLU-23            [-1, 512, 6, 6]               0
#         MaxPool2d-24            [-1, 512, 3, 3]               0
#            Conv2d-25            [-1, 512, 3, 3]       2,359,808
#              ReLU-26            [-1, 512, 3, 3]               0
#            Conv2d-27            [-1, 512, 3, 3]       2,359,808
#              ReLU-28            [-1, 512, 3, 3]               0
#            Conv2d-29            [-1, 512, 3, 3]       2,359,808
#              ReLU-30            [-1, 512, 3, 3]               0
#          Identity-31            [-1, 512, 3, 3]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#          Identity-33                  [-1, 512]               0
# ================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 10.66
# Params size (MB): 56.13
# Estimated Total Size (MB): 66.82
# ----------------------------------------------------------------

# %% [markdown]
# Note:
# * 在 avgpool 和 classifier 之間， vgg16 模型會把 (-1, 512, 1, 1) reshape 成 (-1, 512)。
# * 每一個 (3, 50, 50) 的影像經過更改後的 vgg16 模型就會產生 512 個 feature 。

# %% [markdown]
# ### 3. 增加影像之外的變數(ex. 性別, 年齡, ...)去建立 classifier layers
#
# 這裡想建立一個特徵層可以考慮剛剛影像經過特徵層所得到的 512 個數值和性別，年齡這兩個數值，所以分類層的一開始會有 512+2 = 514 個神經元。

# %%
del vgg16

# %%
def main():
    seed_everything(config.seed)
    
    # train dataframe
    train_data = pd.read_csv(os.path.join(config.root, 'train.csv'))
    
    
    # TODO_4: split the training dataset，通常是 8:2，但可以嘗試其他的分法，e.g. 7:3。
    
    
    # split training & validation dataset 
    train_dataset, val_dataset = train_test_split(train_data, train_size = 0.8, test_size = 0.2, random_state = config.seed)

    train_dataset = ParkinsonsDataset(train_dataset, transforms = build_transform(True), mode = "train")
    val_dataset = ParkinsonsDataset(val_dataset, transforms = build_transform(False), mode = "valid")
    
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = config.batch_size, shuffle = True)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = config.batch_size, shuffle = False)
    

    # settings
    print("Initializing model...")
    
    model = VGGplus(num_classes = config.num_classes, features_grad = True)
    
    model.to(config.device)
    
    criterion = nn.CrossEntropyLoss().to(config.device)
    
    parameters = [p for p in model.parameters() if p.requires_grad] 
    
    # TODO_5: 調整適當的 optimizer、scheduler。
    
    optimizer = torch.optim.Adam(parameters, lr = config.lr, weight_decay = config.weight_decay) 
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer = optimizer,
        epochs = config.epochs,
        steps_per_epoch = train_loader.__len__(),
        max_lr = config.lr,
        anneal_strategy = 'cos'
    )

    # recordings
    best_val_loss = float("inf")
    history = {
        "train": {
            "loss": [],
            "acc": [],
            "f1": [],
            "misclass": []
        },
        "valid": {
            "loss": [],
            "acc": [],
            "f1": [],
            "misclass": []
        },
    }
    for epoch in range(config.epochs):
        train_loss, train_acc, train_f1, train_misclass = train_one_epoch(model, train_loader, optimizer, scheduler, criterion, config.device)
        valid_loss, valid_acc, valid_f1, valid_misclass = validation(model, val_loader, criterion, config.device)
        
        # Log the loss and validation result
        history["train"]["loss"].append(train_loss)
        history["train"]["acc"].append(train_acc)
        history["train"]["f1"].append(train_f1)
        history["train"]["misclass"].append(train_misclass)
        history["valid"]["loss"].append(valid_loss)
        history["valid"]["acc"].append(valid_acc)
        history["valid"]["f1"].append(valid_f1)
        history["valid"]["misclass"].append(valid_misclass)

        print(f'Epoch[{epoch+1}/{config.epochs}], Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, Train F1: {train_f1:.2f}% | Valid Loss: {valid_loss:.4f}, Valid Acc: {valid_acc:.2f}%, Valid F1: {valid_f1:.2f}%, Valid Misclass: {valid_misclass:.2f}% | LR: {optimizer.state_dict()["param_groups"][0]["lr"]:.6f}')
        
        if valid_loss < best_val_loss:
            save_file = {
                "model": model.state_dict(),
                "optimizer": optimizer.state_dict(),
                "scheduler": scheduler.state_dict(),
                "epoch": epoch,
                "args": config
            }
            best_val_loss = valid_loss
            torch.save(save_file, "checkpoint.pth")

        best_ckpt = torch.load("checkpoint.pth", map_location = config.device, weights_only = False)
        model.load_state_dict(best_ckpt["model"])

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(config.epochs), history["train"]["loss"], label='Training Loss')
    plt.plot(range(config.epochs), history["valid"]["loss"], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss Curves')
    plt.show()

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(config.epochs), history["train"]["acc"], label='Training Acc')
    plt.plot(range(config.epochs), history["valid"]["acc"], label='Validation Acc')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy Curves')
    plt.show()

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(config.epochs), history["train"]["f1"], label='Training F1')
    plt.plot(range(config.epochs), history["valid"]["f1"], label='Validation F1')
    plt.xlabel('Epoch')
    plt.ylabel('F1 Score')
    plt.legend()
    plt.title('Training and Validation F1 Score Curves')
    plt.show()
    
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(config.epochs), history["train"]["misclass"], label='Training misclassification')
    plt.plot(range(config.epochs), history["valid"]["misclass"], label='Validation misclassification')
    plt.xlabel('Epoch')
    plt.ylabel('misclassification')
    plt.legend()
    plt.title('Training and Validation misclassification Curves')
    plt.show()
    
    
    # TODO_6: 畫出 train 跟 valid 的 Misclassification Rate 圖。
   
    

if __name__ == "__main__":
    main()
# Out:
# Initializing model...
# Epoch[1/100], Train Loss: 1.1368, Train Acc: 30.47%, Train F1: 23.35% | Valid Loss: 1.3256, Valid Acc: 57.58%, Valid F1: 42.47%, Valid Misclass: 42.42% | LR: 0.000004
# Epoch[2/100], Train Loss: 1.0923, Train Acc: 50.78%, Train F1: 32.02% | Valid Loss: 1.2807, Valid Acc: 48.48%, Valid F1: 27.35%, Valid Misclass: 51.52% | LR: 0.000004
# Epoch[3/100], Train Loss: 1.0675, Train Acc: 50.00%, Train F1: 28.76% | Valid Loss: 1.2470, Valid Acc: 45.45%, Valid F1: 21.28%, Valid Misclass: 54.55% | LR: 0.000004
# Epoch[4/100], Train Loss: 1.0454, Train Acc: 47.66%, Train F1: 23.30% | Valid Loss: 1.2182, Valid Acc: 45.45%, Valid F1: 20.83%, Valid Misclass: 54.55% | LR: 0.000004
# Epoch[5/100], Train Loss: 1.0255, Train Acc: 47.66%, Train F1: 23.30% | Valid Loss: 1.1931, Valid Acc: 45.45%, Valid F1: 20.83%, Valid Misclass: 54.55% | LR: 0.000004
# Epoch[6/100], Train Loss: 1.0101, Train Acc: 47.66%, Train F1: 23.30% | Valid Loss: 1.1676, Valid Acc: 45.45%, Valid F1: 20.83%, Valid Misclass: 54.55% | LR: 0.000004
# Epoch[7/100], Train Loss: 0.9940, Train Acc: 47.66%, Train F1: 23.30% | Valid Loss: 1.1425, Valid Acc: 45.45%, Valid F1: 20.83%, Valid Misclass: 54.55% | LR: 0.000004
# Epoch[8/100], Train Loss: 0.9793, Train Acc: 47.66%, Train F1: 23.41% | Valid Loss: 1.1124, Valid Acc: 48.48%, Valid F1: 27.34%, Valid Misclass: 51.52% | LR: 0.000004
# Epoch[9/100], Train Loss: 0.9598, Train Acc: 48.44%, Train F1: 25.33% | Valid Loss: 1.0853, Valid Acc: 48.48%, Valid F1: 27.34%, Valid Misclass: 51.52% | LR: 0.000004
# Epoch[10/100], Train Loss: 0.9386, Train Acc: 49.22%, Train F1: 27.14% | Valid Loss: 1.0545, Valid Acc: 48.48%, Valid F1: 27.34%, Valid Misclass: 51.52% | LR: 0.000004
# Epoch[11/100], Train Loss: 0.9166, Train Acc: 50.00%, Train F1: 28.88% | Valid Loss: 1.0264, Valid Acc: 48.48%, Valid F1: 27.78%, Valid Misclass: 51.52% | LR: 0.000005
# Epoch[12/100], Train Loss: 0.8893, Train Acc: 50.00%, Train F1: 31.49% | Valid Loss: 0.9962, Valid Acc: 51.52%, Valid F1: 32.98%, Valid Misclass: 48.48% | LR: 0.000005
# Epoch[13/100], Train Loss: 0.8629, Train Acc: 53.12%, Train F1: 38.34% | Valid Loss: 0.9627, Valid Acc: 54.55%, Valid F1: 37.72%, Valid Misclass: 45.45% | LR: 0.000005
# Epoch[14/100], Train Loss: 0.8303, Train Acc: 57.81%, Train F1: 46.47% | Valid Loss: 0.9254, Valid Acc: 54.55%, Valid F1: 38.82%, Valid Misclass: 45.45% | LR: 0.000005
# Epoch[15/100], Train Loss: 0.7961, Train Acc: 63.28%, Train F1: 55.54% | Valid Loss: 0.8863, Valid Acc: 60.61%, Valid F1: 48.82%, Valid Misclass: 39.39% | LR: 0.000005
# Epoch[16/100], Train Loss: 0.7611, Train Acc: 68.75%, Train F1: 63.35% | Valid Loss: 0.8453, Valid Acc: 75.76%, Valid F1: 66.81%, Valid Misclass: 24.24% | LR: 0.000005
# Epoch[17/100], Train Loss: 0.7196, Train Acc: 71.09%, Train F1: 67.36% | Valid Loss: 0.8047, Valid Acc: 75.76%, Valid F1: 66.81%, Valid Misclass: 24.24% | LR: 0.000005
# Epoch[18/100], Train Loss: 0.6809, Train Acc: 72.66%, Train F1: 69.62% | Valid Loss: 0.7715, Valid Acc: 72.73%, Valid F1: 63.89%, Valid Misclass: 27.27% | LR: 0.000005
# Epoch[19/100], Train Loss: 0.6395, Train Acc: 75.00%, Train F1: 72.28% | Valid Loss: 0.7477, Valid Acc: 75.76%, Valid F1: 67.31%, Valid Misclass: 24.24% | LR: 0.000005
# Epoch[20/100], Train Loss: 0.6016, Train Acc: 80.47%, Train F1: 78.22% | Valid Loss: 0.7170, Valid Acc: 72.73%, Valid F1: 64.61%, Valid Misclass: 27.27% | LR: 0.000006
# Epoch[21/100], Train Loss: 0.5629, Train Acc: 82.03%, Train F1: 80.29% | Valid Loss: 0.6691, Valid Acc: 69.70%, Valid F1: 64.72%, Valid Misclass: 30.30% | LR: 0.000006
# Epoch[22/100], Train Loss: 0.5258, Train Acc: 85.16%, Train F1: 84.17% | Valid Loss: 0.6500, Valid Acc: 72.73%, Valid F1: 66.77%, Valid Misclass: 27.27% | LR: 0.000006
# Epoch[23/100], Train Loss: 0.4838, Train Acc: 82.81%, Train F1: 81.47% | Valid Loss: 0.6392, Valid Acc: 72.73%, Valid F1: 66.77%, Valid Misclass: 27.27% | LR: 0.000006
# Epoch[24/100], Train Loss: 0.4474, Train Acc: 87.50%, Train F1: 86.69% | Valid Loss: 0.6395, Valid Acc: 72.73%, Valid F1: 64.61%, Valid Misclass: 27.27% | LR: 0.000006
# Epoch[25/100], Train Loss: 0.4438, Train Acc: 87.50%, Train F1: 86.80% | Valid Loss: 0.6197, Valid Acc: 72.73%, Valid F1: 66.77%, Valid Misclass: 27.27% | LR: 0.000007
# Epoch[26/100], Train Loss: 0.4119, Train Acc: 88.28%, Train F1: 87.27% | Valid Loss: 0.6418, Valid Acc: 69.70%, Valid F1: 62.66%, Valid Misclass: 30.30% | LR: 0.000007
# Epoch[27/100], Train Loss: 0.4298, Train Acc: 83.59%, Train F1: 82.10% | Valid Loss: 0.6234, Valid Acc: 72.73%, Valid F1: 66.77%, Valid Misclass: 27.27% | LR: 0.000007
# Epoch[28/100], Train Loss: 0.4193, Train Acc: 87.50%, Train F1: 86.30% | Valid Loss: 0.6461, Valid Acc: 69.70%, Valid F1: 62.66%, Valid Misclass: 30.30% | LR: 0.000007
# Epoch[29/100], Train Loss: 0.4041, Train Acc: 89.06%, Train F1: 88.23% | Valid Loss: 0.6370, Valid Acc: 72.73%, Valid F1: 66.77%, Valid Misclass: 27.27% | LR: 0.000007
# Epoch[30/100], Train Loss: 0.3988, Train Acc: 89.84%, Train F1: 89.15% | Valid Loss: 0.6244, Valid Acc: 72.73%, Valid F1: 66.77%, Valid Misclass: 27.27% | LR: 0.000008
# Epoch[31/100], Train Loss: 0.3963, Train Acc: 92.19%, Train F1: 91.83% | Valid Loss: 0.6244, Valid Acc: 72.73%, Valid F1: 66.77%, Valid Misclass: 27.27% | LR: 0.000008
# Epoch[32/100], Train Loss: 0.4016, Train Acc: 87.50%, Train F1: 86.78% | Valid Loss: 0.6507, Valid Acc: 72.73%, Valid F1: 64.61%, Valid Misclass: 27.27% | LR: 0.000008
# Epoch[33/100], Train Loss: 0.4102, Train Acc: 86.72%, Train F1: 85.66% | Valid Loss: 0.6126, Valid Acc: 72.73%, Valid F1: 66.77%, Valid Misclass: 27.27% | LR: 0.000008
# Epoch[34/100], Train Loss: 0.3641, Train Acc: 90.62%, Train F1: 90.15% | Valid Loss: 0.6290, Valid Acc: 69.70%, Valid F1: 61.85%, Valid Misclass: 30.30% | LR: 0.000009
# Epoch[35/100], Train Loss: 0.3565, Train Acc: 89.84%, Train F1: 89.31% | Valid Loss: 0.6340, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000009
# Epoch[36/100], Train Loss: 0.3612, Train Acc: 90.62%, Train F1: 89.82% | Valid Loss: 0.6663, Valid Acc: 72.73%, Valid F1: 64.61%, Valid Misclass: 27.27% | LR: 0.000009
# Epoch[37/100], Train Loss: 0.3635, Train Acc: 88.28%, Train F1: 87.11% | Valid Loss: 0.6063, Valid Acc: 72.73%, Valid F1: 66.77%, Valid Misclass: 27.27% | LR: 0.000010
# Epoch[38/100], Train Loss: 0.3054, Train Acc: 95.31%, Train F1: 94.84% | Valid Loss: 0.6623, Valid Acc: 75.76%, Valid F1: 66.60%, Valid Misclass: 24.24% | LR: 0.000010
# Epoch[39/100], Train Loss: 0.3118, Train Acc: 92.19%, Train F1: 91.74% | Valid Loss: 0.6357, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000010
# Epoch[40/100], Train Loss: 0.3023, Train Acc: 96.09%, Train F1: 95.99% | Valid Loss: 0.6386, Valid Acc: 72.73%, Valid F1: 64.61%, Valid Misclass: 27.27% | LR: 0.000010
# Epoch[41/100], Train Loss: 0.3033, Train Acc: 92.97%, Train F1: 92.56% | Valid Loss: 0.6454, Valid Acc: 72.73%, Valid F1: 63.73%, Valid Misclass: 27.27% | LR: 0.000011
# Epoch[42/100], Train Loss: 0.3059, Train Acc: 94.53%, Train F1: 94.30% | Valid Loss: 0.6421, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000011
# Epoch[43/100], Train Loss: 0.3012, Train Acc: 93.75%, Train F1: 93.47% | Valid Loss: 0.6377, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000011
# Epoch[44/100], Train Loss: 0.3044, Train Acc: 95.31%, Train F1: 95.04% | Valid Loss: 0.6432, Valid Acc: 72.73%, Valid F1: 64.61%, Valid Misclass: 27.27% | LR: 0.000012
# Epoch[45/100], Train Loss: 0.3066, Train Acc: 93.75%, Train F1: 93.35% | Valid Loss: 0.6534, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000012
# Epoch[46/100], Train Loss: 0.3066, Train Acc: 93.75%, Train F1: 93.22% | Valid Loss: 0.6244, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000013
# Epoch[47/100], Train Loss: 0.3144, Train Acc: 92.97%, Train F1: 92.35% | Valid Loss: 0.6738, Valid Acc: 75.76%, Valid F1: 66.60%, Valid Misclass: 24.24% | LR: 0.000013
# Epoch[48/100], Train Loss: 0.3132, Train Acc: 91.41%, Train F1: 90.68% | Valid Loss: 0.6137, Valid Acc: 72.73%, Valid F1: 66.77%, Valid Misclass: 27.27% | LR: 0.000013
# Epoch[49/100], Train Loss: 0.3132, Train Acc: 92.97%, Train F1: 92.37% | Valid Loss: 0.6792, Valid Acc: 72.73%, Valid F1: 63.73%, Valid Misclass: 27.27% | LR: 0.000014
# Epoch[50/100], Train Loss: 0.3275, Train Acc: 89.84%, Train F1: 88.40% | Valid Loss: 0.6443, Valid Acc: 69.70%, Valid F1: 62.66%, Valid Misclass: 30.30% | LR: 0.000014
# Epoch[51/100], Train Loss: 0.3062, Train Acc: 94.53%, Train F1: 94.28% | Valid Loss: 0.6352, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000014
# Epoch[52/100], Train Loss: 0.3121, Train Acc: 94.53%, Train F1: 94.22% | Valid Loss: 0.6492, Valid Acc: 75.76%, Valid F1: 66.60%, Valid Misclass: 24.24% | LR: 0.000015
# Epoch[53/100], Train Loss: 0.2994, Train Acc: 93.75%, Train F1: 93.54% | Valid Loss: 0.6237, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000015
# Epoch[54/100], Train Loss: 0.2973, Train Acc: 93.75%, Train F1: 93.54% | Valid Loss: 0.6370, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000016
# Epoch[55/100], Train Loss: 0.3128, Train Acc: 93.75%, Train F1: 93.29% | Valid Loss: 0.6941, Valid Acc: 72.73%, Valid F1: 63.89%, Valid Misclass: 27.27% | LR: 0.000016
# Epoch[56/100], Train Loss: 0.2967, Train Acc: 95.31%, Train F1: 95.05% | Valid Loss: 0.6538, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000016
# Epoch[57/100], Train Loss: 0.3223, Train Acc: 92.19%, Train F1: 91.65% | Valid Loss: 0.6247, Valid Acc: 72.73%, Valid F1: 66.77%, Valid Misclass: 27.27% | LR: 0.000017
# Epoch[58/100], Train Loss: 0.3006, Train Acc: 92.97%, Train F1: 92.46% | Valid Loss: 0.6150, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000017
# Epoch[59/100], Train Loss: 0.2935, Train Acc: 93.75%, Train F1: 93.54% | Valid Loss: 0.6463, Valid Acc: 72.73%, Valid F1: 64.61%, Valid Misclass: 27.27% | LR: 0.000018
# Epoch[60/100], Train Loss: 0.3025, Train Acc: 92.97%, Train F1: 92.55% | Valid Loss: 0.6756, Valid Acc: 72.73%, Valid F1: 63.73%, Valid Misclass: 27.27% | LR: 0.000018
# Epoch[61/100], Train Loss: 0.3050, Train Acc: 92.19%, Train F1: 91.61% | Valid Loss: 0.6527, Valid Acc: 75.76%, Valid F1: 66.60%, Valid Misclass: 24.24% | LR: 0.000019
# Epoch[62/100], Train Loss: 0.2978, Train Acc: 91.41%, Train F1: 91.01% | Valid Loss: 0.6313, Valid Acc: 72.73%, Valid F1: 64.61%, Valid Misclass: 27.27% | LR: 0.000019
# Epoch[63/100], Train Loss: 0.3101, Train Acc: 92.97%, Train F1: 92.28% | Valid Loss: 0.6513, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000020
# Epoch[64/100], Train Loss: 0.3105, Train Acc: 92.19%, Train F1: 91.64% | Valid Loss: 0.6178, Valid Acc: 72.73%, Valid F1: 66.77%, Valid Misclass: 27.27% | LR: 0.000020
# Epoch[65/100], Train Loss: 0.3205, Train Acc: 92.19%, Train F1: 91.46% | Valid Loss: 0.7020, Valid Acc: 75.76%, Valid F1: 66.60%, Valid Misclass: 24.24% | LR: 0.000020
# Epoch[66/100], Train Loss: 0.2996, Train Acc: 92.97%, Train F1: 92.59% | Valid Loss: 0.5985, Valid Acc: 69.70%, Valid F1: 64.72%, Valid Misclass: 30.30% | LR: 0.000021
# Epoch[67/100], Train Loss: 0.2155, Train Acc: 96.09%, Train F1: 95.96% | Valid Loss: 0.7059, Valid Acc: 72.73%, Valid F1: 63.89%, Valid Misclass: 27.27% | LR: 0.000021
# Epoch[68/100], Train Loss: 0.2151, Train Acc: 95.31%, Train F1: 95.05% | Valid Loss: 0.6261, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000022
# Epoch[69/100], Train Loss: 0.2214, Train Acc: 96.88%, Train F1: 96.74% | Valid Loss: 0.6461, Valid Acc: 75.76%, Valid F1: 66.60%, Valid Misclass: 24.24% | LR: 0.000022
# Epoch[70/100], Train Loss: 0.2149, Train Acc: 95.31%, Train F1: 95.01% | Valid Loss: 0.6626, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000023
# Epoch[71/100], Train Loss: 0.2304, Train Acc: 95.31%, Train F1: 95.16% | Valid Loss: 0.6450, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000023
# Epoch[72/100], Train Loss: 0.2252, Train Acc: 96.88%, Train F1: 96.74% | Valid Loss: 0.6170, Valid Acc: 72.73%, Valid F1: 63.73%, Valid Misclass: 27.27% | LR: 0.000024
# Epoch[73/100], Train Loss: 0.2240, Train Acc: 95.31%, Train F1: 95.05% | Valid Loss: 0.6999, Valid Acc: 75.76%, Valid F1: 66.60%, Valid Misclass: 24.24% | LR: 0.000024
# Epoch[74/100], Train Loss: 0.2067, Train Acc: 96.88%, Train F1: 96.74% | Valid Loss: 0.6599, Valid Acc: 72.73%, Valid F1: 63.89%, Valid Misclass: 27.27% | LR: 0.000025
# Epoch[75/100], Train Loss: 0.2175, Train Acc: 92.97%, Train F1: 92.22% | Valid Loss: 0.8220, Valid Acc: 78.79%, Valid F1: 65.32%, Valid Misclass: 21.21% | LR: 0.000025
# Epoch[76/100], Train Loss: 0.2151, Train Acc: 96.88%, Train F1: 96.71% | Valid Loss: 0.6546, Valid Acc: 78.79%, Valid F1: 73.59%, Valid Misclass: 21.21% | LR: 0.000026
# Epoch[77/100], Train Loss: 0.2265, Train Acc: 95.31%, Train F1: 95.03% | Valid Loss: 0.7064, Valid Acc: 75.76%, Valid F1: 66.60%, Valid Misclass: 24.24% | LR: 0.000027
# Epoch[78/100], Train Loss: 0.2262, Train Acc: 95.31%, Train F1: 95.21% | Valid Loss: 0.6312, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000027
# Epoch[79/100], Train Loss: 0.2418, Train Acc: 93.75%, Train F1: 93.33% | Valid Loss: 0.7673, Valid Acc: 69.70%, Valid F1: 58.08%, Valid Misclass: 30.30% | LR: 0.000028
# Epoch[80/100], Train Loss: 0.2919, Train Acc: 91.41%, Train F1: 89.91% | Valid Loss: 0.6574, Valid Acc: 63.64%, Valid F1: 58.77%, Valid Misclass: 36.36% | LR: 0.000028
# Epoch[81/100], Train Loss: 0.3636, Train Acc: 85.16%, Train F1: 84.33% | Valid Loss: 0.8133, Valid Acc: 78.79%, Valid F1: 65.32%, Valid Misclass: 21.21% | LR: 0.000029
# Epoch[82/100], Train Loss: 0.3289, Train Acc: 88.28%, Train F1: 87.00% | Valid Loss: 0.7836, Valid Acc: 72.73%, Valid F1: 61.20%, Valid Misclass: 27.27% | LR: 0.000029
# Epoch[83/100], Train Loss: 0.2512, Train Acc: 89.06%, Train F1: 87.87% | Valid Loss: 0.7044, Valid Acc: 75.76%, Valid F1: 67.68%, Valid Misclass: 24.24% | LR: 0.000030
# Epoch[84/100], Train Loss: 0.2211, Train Acc: 97.66%, Train F1: 97.47% | Valid Loss: 0.6012, Valid Acc: 69.70%, Valid F1: 64.72%, Valid Misclass: 30.30% | LR: 0.000030
# Epoch[85/100], Train Loss: 0.2365, Train Acc: 95.31%, Train F1: 95.21% | Valid Loss: 0.6263, Valid Acc: 72.73%, Valid F1: 63.73%, Valid Misclass: 27.27% | LR: 0.000031
# Epoch[86/100], Train Loss: 0.2804, Train Acc: 92.19%, Train F1: 91.94% | Valid Loss: 0.8680, Valid Acc: 66.67%, Valid F1: 51.63%, Valid Misclass: 33.33% | LR: 0.000032
# Epoch[87/100], Train Loss: 0.3291, Train Acc: 86.72%, Train F1: 84.91% | Valid Loss: 0.5828, Valid Acc: 63.64%, Valid F1: 60.63%, Valid Misclass: 36.36% | LR: 0.000032
# Epoch[88/100], Train Loss: 0.2501, Train Acc: 91.41%, Train F1: 91.08% | Valid Loss: 0.8459, Valid Acc: 69.70%, Valid F1: 58.95%, Valid Misclass: 30.30% | LR: 0.000033
# Epoch[89/100], Train Loss: 0.3670, Train Acc: 82.03%, Train F1: 80.68% | Valid Loss: 0.7729, Valid Acc: 75.76%, Valid F1: 70.60%, Valid Misclass: 24.24% | LR: 0.000033
# Epoch[90/100], Train Loss: 0.2624, Train Acc: 89.84%, Train F1: 89.20% | Valid Loss: 1.0150, Valid Acc: 66.67%, Valid F1: 55.92%, Valid Misclass: 33.33% | LR: 0.000034
# Epoch[91/100], Train Loss: 0.1602, Train Acc: 96.09%, Train F1: 95.68% | Valid Loss: 0.6833, Valid Acc: 75.76%, Valid F1: 68.87%, Valid Misclass: 24.24% | LR: 0.000034
# Epoch[92/100], Train Loss: 0.1687, Train Acc: 96.09%, Train F1: 95.76% | Valid Loss: 0.7940, Valid Acc: 75.76%, Valid F1: 66.60%, Valid Misclass: 24.24% | LR: 0.000035
# Epoch[93/100], Train Loss: 0.1556, Train Acc: 99.22%, Train F1: 99.24% | Valid Loss: 0.7121, Valid Acc: 75.76%, Valid F1: 66.60%, Valid Misclass: 24.24% | LR: 0.000036
# Epoch[94/100], Train Loss: 0.1653, Train Acc: 96.88%, Train F1: 96.72% | Valid Loss: 0.6768, Valid Acc: 69.70%, Valid F1: 62.66%, Valid Misclass: 30.30% | LR: 0.000036
# Epoch[95/100], Train Loss: 0.1639, Train Acc: 97.66%, Train F1: 97.50% | Valid Loss: 0.8439, Valid Acc: 72.73%, Valid F1: 63.89%, Valid Misclass: 27.27% | LR: 0.000037
# Epoch[96/100], Train Loss: 0.1470, Train Acc: 99.22%, Train F1: 99.02% | Valid Loss: 0.6991, Valid Acc: 75.76%, Valid F1: 66.60%, Valid Misclass: 24.24% | LR: 0.000037
# Epoch[97/100], Train Loss: 0.1461, Train Acc: 99.22%, Train F1: 99.24% | Valid Loss: 0.8047, Valid Acc: 69.70%, Valid F1: 58.08%, Valid Misclass: 30.30% | LR: 0.000038
# Epoch[98/100], Train Loss: 0.1579, Train Acc: 96.88%, Train F1: 96.33% | Valid Loss: 0.9182, Valid Acc: 75.76%, Valid F1: 63.16%, Valid Misclass: 24.24% | LR: 0.000039
# Epoch[99/100], Train Loss: 0.2021, Train Acc: 92.97%, Train F1: 92.08% | Valid Loss: 0.9960, Valid Acc: 72.73%, Valid F1: 61.20%, Valid Misclass: 27.27% | LR: 0.000039
# Epoch[100/100], Train Loss: 0.1711, Train Acc: 98.44%, Train F1: 98.26% | Valid Loss: 0.6704, Valid Acc: 66.67%, Valid F1: 60.00%, Valid Misclass: 33.33% | LR: 0.000040

# %% [markdown]
# ## Redefined Resnet

# %%
# TODO_7: 用跟 VGG 類似的方式建立 Resnet

class ResNetplus(nn.Module):
    def __init__(self, num_classes, input_size = (3, 50, 50), features_grad = False):
        super().__init__()
        
        resnet50 = models.resnet50(weights = 'IMAGENET1K_V1', progress = True) # 這邊若想用其他 resnet 模型也行

# %% [markdown]
# ## Redefined VIT

# %%
# TODO_7: 建立 VIT(下次助教課會講到)

# %% [markdown]
# ## testing

# %%
def testing(model, test_loader, device):
    model.eval()
    preds = []
    with torch.no_grad(): 
        for image, age, gender in test_loader:
            image = image.to(device = device, dtype = torch.float)
            age = age.to(device)
            gender = gender.to(device)
            logits = model(image, age, gender)
            pred = torch.argmax(logits, dim = 1)
            preds.append(pred)

    preds = torch.cat(preds)
    
    # TODO_8: 因為輸出的 preds為 0,1,2，所以請調整成 1,2,3。
    preds = 
    
    return preds

# %%
seed_everything(config.seed)
test_data = pd.read_csv(os.path.join(config.root, 'test.csv'))

# TODO_9: 填寫 test_dataset、test_loader、model 四個空格，記得 test_loader 的 shuffle = False。

test_dataset = 
test_loader = 
model = 


model.to(config.device)

best_ckpt = torch.load(f"checkpoint.pth")
model.load_state_dict(best_ckpt["model"])

preds = testing(model, test_loader, config.device)

# %%
# TODO_10: 將 .csv 取名。

df = pd.read_csv(os.path.join(config.root, 'submission.csv'))
df = pd.DataFrame(df)
df['Stage'] = preds.cpu().numpy() # 將 preds 從 GPU 轉移到 CPU 並轉換為 NumPy 陣列
df.to_csv('.csv',index = False, header = True)
