# %% [markdown]
# # Homework 2 : 單光子電腦斷層掃描的多類別分類
# 在這份作業中，請各位將 TODO 填寫好。
#
# 1. 調整適當的參數。
# 2. 將 validation 空白處填起來讓程式能夠運作
# 3. 寫出當 mode = valid、test 的 getitem()。
# 4. split the training dataset。
# 5. 調整適當的 optimizer、scheduler，雖然不一定會比較好，但可以嘗試看看。
# 6. 畫出 train 跟 valid 的 Misclassification Rate 圖。
# 7. 用相似的手法建立 Resnet, VIT model 架構。
# 8. 在 testing 裡填空格。
# 9. 填寫 test_dataset、test_loader、model 三個空格。
# 10. 挑選你認為最好的 model 並將預測結果輸出在 submission.csv。

# %% [markdown]
# kaggle rule:
# 1. 不得使用兩隻以上的帳號繳交 submission檔案 (可參加但不可丟答案)
# 2. team的名稱記得一定要改成學號

# %% [markdown]
# ## Import Packages

# %%
# torchsummary 可以讓模型視覺化，以及匯出模型每層的詳細數量和每層的比例。
# !pip install torchsummary

# %%
import pydicom
import pandas as pd
import numpy as np
import os
import random

import pydicom
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import Dataset, Subset, DataLoader
from torchvision.transforms import v2
import torchvision.models as models # VGG16, ResNet50
from torchsummary import summary # summary for models

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score

print(torch.__version__)
print(torch.version.cuda)
print(torch.backends.cudnn.version())
print(torch.cuda.is_available())

import warnings
warnings.filterwarnings("ignore", category = FutureWarning)
# Out:
# 2.4.1+cu118
# 11.8
# 90100
# True

# %% [markdown]
# ## Configuration

# %%
# TODO_1: 調整適當的參數(除了 num_classes，你可以任意調整以下的超參數)

class config:
    
    root = "./hwk02_data" #"/kaggle/input/2024dl"
    batch_size = 16
    lr = 1e-4
    epochs = 150
    weight_decay = 1e-3
    seed = 18
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    num_classes = 3
    
print('device:', config.device)
# Out:
# device: cuda

# %% [markdown]
# ## Input Data

# %%
train_data = pd.read_csv(os.path.join(config.root, 'train.csv'))
test_data = pd.read_csv(os.path.join(config.root, 'test.csv'))

print(f'Number of training samples: {train_data.shape[0]}')
print(f'Number of testing samples: {test_data.shape[0]}')
# Out:
# Number of training samples: 161
# Number of testing samples: 41

# %%
train_data['Stage'].value_counts().sort_index()
# Out:
# Stage
# 1    44
# 2    42
# 3    75
# Name: count, dtype: int64

# %%
def seed_everything(seed):
    # Set Python random seed
    random.seed(seed)
    
    # Set NumPy random seed
    np.random.seed(seed)
    
    # Set PyTorch random seed for CPU and GPU
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    
    # Set PyTorch deterministic operations for cudnn backend
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


def evaluator(preds, gts):
    preds = preds.cpu().numpy() if isinstance(preds, torch.Tensor) else preds
    gts = gts.cpu().numpy() if isinstance(gts, torch.Tensor) else gts
    acc = accuracy_score(preds, gts)
    f1 = f1_score(preds, gts, average = "macro")
    misclassification_rate = 1 - acc
    
    return acc, f1, misclassification_rate

def train_one_epoch(model, train_loader, optimizer, scheduler, criterion, device):
    # 作用是啟用 batch normalization 和 dropout。
    # 保證 BN 層能夠用到每個 batch 資料的平均值和變異數。對於 Dropout 是隨機取一部分網路連線來訓練更新參數。
    model.train() 
    
    train_loss = .0
    predictions, ground_truths = [], []
    
    for images, ages, genders, labels in train_loader:
        images = images.to(device = device, dtype = torch.float)
        ages = ages.to(device = device, dtype = torch.float)
        genders = genders.to(device = device, dtype = torch.float)
        labels = labels.to(device = device, dtype = torch.long)

        optimizer.zero_grad()
        logits = model(images, ages, genders)
        
        # Pytorch 中的分類損失函數（如 CrossEntropyLoss）期望 label 為 0 開始的整數。
        labels = torch.sub(labels, 1) # labels 1, 2, 3 -> 0, 1, 2
        loss = criterion(logits, labels)
        loss.backward()

        optimizer.step()
        # scheduler.step() #switch place

        train_loss += loss.item()
        preds = torch.argmax(logits, dim = 1)

        predictions.append(preds)
        ground_truths.append(labels)
    scheduler.step()

    train_loss /= len(train_loader)

    predictions = torch.cat(predictions)
    ground_truths = torch.cat(ground_truths)
    train_acc, train_f1, train_misclass = evaluator(predictions, ground_truths)

    return train_loss, 100*train_acc, 100*train_f1, 100*train_misclass


def validation(model, valid_loader, criterion, device):
    # 確保 BN 層能夠用全部訓練資料的平均值和變異數，即驗證過程中要保證 BN 層的平均值和變異數不變。對於 Dropout 是利用了所有網路連接，即不進行隨機捨棄神經元。
    # pytorch 會自動把 BN 和 DropOut 固定住，不會取平均，而是用訓練好的數值。
    model.eval()
    valid_loss = .0
    predictions, ground_truths = [], []

    # TODO_2: 請將空白處填起來讓程式能夠運作。

    # 這邊禁用 PyTorch 梯度的自動計算，因為在 validation 階段我們不需要更新 model 的權重，因此不需要進行反向傳播(backpropagation)和梯度計算。
    with torch.no_grad():
        for images, ages, genders, labels in valid_loader:
            # Move data to the device (GPU or CPU)
            images = images.to(device=device, dtype=torch.float)
            ages = ages.to(device=device, dtype=torch.float)
            genders = genders.to(device=device, dtype=torch.float)
            labels = labels.to(device=device, dtype=torch.long)

            # Forward pass: compute logits
            logits = model(images, ages, genders)
            
            # Adjust labels: converting from [1,2,3] to [0,1,2] as expected by CrossEntropyLoss
            labels = torch.sub(labels, 1)
            
            # Compute loss
            loss = criterion(logits, labels)

            # Accumulate validation loss
            valid_loss += loss.item()

            # Get predictions: select the index with the highest logit
            preds = torch.argmax(logits, dim=1)

            # Append predictions and ground truths for evaluation
            predictions.append(preds)
            ground_truths.append(labels)

        # Average validation loss over the entire dataset
        valid_loss /= len(valid_loader)

        # Concatenate all predictions and ground truths from different batches
        predictions = torch.cat(predictions)
        ground_truths = torch.cat(ground_truths)

        # Calculate validation accuracy, F1 score, and misclassification rate
        valid_acc, valid_f1, valid_misclass = evaluator(predictions, ground_truths)
        
    return valid_loss, 100*valid_acc, 100*valid_f1, 100*valid_misclass


def printTrainresult(history, eps):
    train_loss=history["train"]["loss"][eps]
    train_acc=history["train"]["acc"][eps]
    train_f1=history["train"]["f1"][eps]
    train_misclass=history["train"]["misclass"][eps]
    valid_loss=history["valid"]["loss"][eps]
    valid_acc=history["valid"]["acc"][eps]
    valid_f1=history["valid"]["f1"][eps]
    valid_misclass=history["valid"]["misclass"][eps]
    
    # Plot loss curves
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(config.epochs), history["train"]["loss"], label='Training Loss')
    plt.plot(range(config.epochs), history["valid"]["loss"], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss Curves')
    plt.show()

    # Plot accuracy curves
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(config.epochs), history["train"]["acc"], label='Training Accuracy')
    plt.plot(range(config.epochs), history["valid"]["acc"], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy Curves')
    plt.show()

    # Plot F1 score curves
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(config.epochs), history["train"]["f1"], label='Training F1 Score')
    plt.plot(range(config.epochs), history["valid"]["f1"], label='Validation F1 Score')
    plt.xlabel('Epoch')
    plt.ylabel('F1 Score')
    plt.legend()
    plt.title('Training and Validation F1 Score Curves')
    plt.show()

    # Plot misclassification rate curves
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(config.epochs), history["train"]["misclass"], label='Training Misclassification')
    plt.plot(range(config.epochs), history["valid"]["misclass"], label='Validation Misclassification')
    plt.xlabel('Epoch')
    plt.ylabel('Misclassification Rate (%)')
    plt.legend()
    plt.title('Training and Validation Misclassification Rate')
    plt.show()
    
    print("BatchSize: ",config.batch_size," / LR: ",config.lr," / WeightDecay: ",config.weight_decay," / Seed: ",config.seed)
    print(f'Best result: Epoch{eps+1},\
        \nTrain Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, Train F1: {train_f1:.2f}% |\
        \nValid Loss: {valid_loss:.4f}, Valid Acc: {valid_acc:.2f}%, Valid F1: {valid_f1:.2f}%, Valid Misclass: {valid_misclass:.2f}%')

# %% [markdown]
# ## Transformation

# %%
class Normalization(object):
    
    def __call__(self, image): # 定義有image之後要進行的資料處理
        changed_image = (image - image.min())/(image.max() - image.min())
        return changed_image

def build_transform(is_train):
    """
    Create a data transformation pipeline for image preprocessing in deep learning tasks.
    """
    t = []
    if is_train:
        # 图像增强变换，适合训练集使用
        # t.append(v2.RandomHorizontalFlip(p=0.5))                  # 随机水平翻转图像
        # t.append(v2.RandomRotation(degrees=5))
        t.append(v2.CenterCrop(size = (50, 50)))
        t.append(Normalization())                                 # 标准化
        return v2.Compose(t)
    
    t.append(v2.CenterCrop(size = (50, 50)))
    t.append(Normalization())
    return v2.Compose(t)

def build_transform_ViT(is_train):
    """
    Create a data transformation pipeline for image preprocessing in deep learning tasks.
    """
    t = []
    if is_train:
        t.append(v2.Grayscale(num_output_channels=1))  # Convert to grayscale
        t.append(v2.CenterCrop(size=(56, 56)))
        t.append(Normalization())
        return v2.Compose(t)
    t.append(v2.Grayscale(num_output_channels=1))  # Convert to grayscale (1 channel)
    t.append(v2.CenterCrop(size=(56, 56)))      # Crop to 56x56
    t.append(Normalization())
    return v2.Compose(t)

# %% [markdown]
# ## Defined Dataset

# %%
class ParkinsonsDataset(torch.utils.data.Dataset):

    def __init__(self, df, mode = None, transforms = None): # 將所有資料提出
        self.df = df
        self.mode = mode
        self.transforms = transforms
        
    def __len__(self):
        return self.df.shape[0]

    def __getitem__(self, x): # 找出指定的資料
        
        age = torch.tensor(self.df.iloc[x, 1]) # 年齡
        gender = torch.tensor(self.df.iloc[x, 2]) # 性別
        index = torch.tensor(self.df.iloc[x, 4]) # 起始張數
        
        # 影像前處理
        image = pydicom.dcmread(config.root + self.df.iloc[x, 3]).pixel_array
        image = torch.tensor(image.astype(np.float32))
        image = image[index-1:index+2, :, :]
        
        if self.mode == "train":
            label = torch.tensor(self.df.iloc[x, 5]) # 標籤
            if self.transforms: image = self.transforms(image)

            return image, age, gender, label
        
        
        # TODO_3: 寫出當 mode = valid、test 的 getitem()
        elif self.mode == "valid":
            # Extract label for validation
            label = torch.tensor(self.df.iloc[x, 5], dtype=torch.long)  # Label for validation
            if self.transforms: image = self.transforms(image)
            return image, age, gender, label

        elif self.mode == "test":
            # In test mode, there is no label to return
            if self.transforms: image = self.transforms(image)
            return image, age, gender

# %% [markdown]
# ## Redefined VGG16

# %%
# VGG: Visual Geometry Group Network (視覺幾何群網絡)
# VGG16 的緣由: VGG 結構中有 13 個卷積層和 3 個全連接層

class VGGplus(nn.Module):
    def __init__(self, num_classes, input_size = (3, 50, 50), features_grad = False): # 默認輸出為分到每一類的機率
        super().__init__()
        
        # 取出 vgg16 中的特徵層
        # vgg16 = models.vgg16_bn(pretrained = True)
        vgg16 = models.vgg16(weights = 'IMAGENET1K_V1', progress = True) # progress = True：顯示下載進度條。
        
        # nn.Identity() 是 Pytorch 中的特殊層，不會改變輸入，只是作為佔位符。這樣你以方便修改模型結構而不會影響其整體的輸出 size
        vgg16.features[30] = nn.Identity()
        
        # 將 VGG16 的輸出特徵圖壓縮 1x1，可以得到一個 512 維的特徵向量，便於與後面的 Fully Connected Layer 結合並處理輸入的不同尺寸的圖像。
        vgg16.avgpool = nn.AdaptiveAvgPool2d(1)
        
        # 移除 VGG16 預設的分類器
        vgg16.classifier = nn.Identity()
        
        # 固定/不固定特徵層的參數值: False/True
        # features_grad: 控制是否對 VGG16 的特徵提取層進行微調(參與梯度計算)
        # 因為資料量不大，因此將 param.requires_grad 設為 False，只訓練新的分類層，減少訓練時間和 overfitting 風險。
        for param in vgg16.features.parameters():
            param.requires_grad = features_grad
        self.backend = vgg16
         
        # # 增加分類層
        # self.classifier = nn.Sequential(
        #   nn.Linear(512 + 2, num_classes) # 512: vgg16 特徵層結果, 2: age & gender
        # )
        

        self.classifier = nn.Sequential(
            nn.Linear(514, 256),
            nn.ReLU(),
            nn.Dropout(0.2),  # 添加 Dropout 层
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, num_classes),
            nn.Softmax(dim=1)
        )
        
        self.softmax = nn.Softmax(dim=1) # 每一個row的總和都是1
        
    
    def forward(self, x, age, gender):
        output = self.backend(x)  # VGG 提取特徵
        output = torch.cat([output, age.view(-1, 1), gender.view(-1, 1)], dim=1)  # 拼接年齡和性別
        output = self.classifier(output)  # 分類器
        return output

# %%
def main():
    seed_everything(config.seed)
    
    # train dataframe
    train_data = pd.read_csv(os.path.join(config.root, 'train.csv'))
    
    
    # TODO_4: split the training dataset，通常是 8:2，但可以嘗試其他的分法，e.g. 7:3。
    train_dataset, val_dataset = train_test_split(train_data, train_size=0.7, test_size=0.3, random_state=config.seed)

    

    train_dataset = ParkinsonsDataset(train_dataset, transforms = build_transform(True), mode = "train")
    val_dataset = ParkinsonsDataset(val_dataset, transforms = build_transform(False), mode = "valid")
    
    
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = config.batch_size, shuffle = True)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = config.batch_size, shuffle = False)
    
    

    # settings
    print("Initializing model...")
    
    model = VGGplus(num_classes = config.num_classes, features_grad = True)
    
    model.to(config.device)
    
    criterion = nn.CrossEntropyLoss().to(config.device)
    
    parameters = [p for p in model.parameters() if p.requires_grad] 
    
    # TODO_5: 調整適當的 optimizer、scheduler。
    
    # optimizer = torch.optim.Adam(parameters, lr = config.lr, weight_decay = config.weight_decay) 
    # scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
    
    optimizer = torch.optim.Adam(model.parameters(), lr = config.lr, weight_decay = config.weight_decay)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer = optimizer,
        epochs = config.epochs,
        steps_per_epoch = train_loader.__len__(),
        max_lr = config.lr,
        anneal_strategy = 'cos'
    )

    # recordings
    best_val_loss = float("inf")
    history = {
        "train": {
            "loss": [],
            "acc": [],
            "f1": [],
            "misclass": []
        },
        "valid": {
            "loss": [],
            "acc": [],
            "f1": [],
            "misclass": []
        },
    }
    besteps= 0
    
    
    
    for epoch in range(config.epochs):
        train_loss, train_acc, train_f1, train_misclass = train_one_epoch(model, train_loader, optimizer, scheduler, criterion, config.device)
        valid_loss, valid_acc, valid_f1, valid_misclass = validation(model, val_loader, criterion, config.device)
        
        # Log the loss and validation result
        history["train"]["loss"].append(train_loss)
        history["train"]["acc"].append(train_acc)
        history["train"]["f1"].append(train_f1)
        history["train"]["misclass"].append(train_misclass)
        history["valid"]["loss"].append(valid_loss)
        history["valid"]["acc"].append(valid_acc)
        history["valid"]["f1"].append(valid_f1)
        history["valid"]["misclass"].append(valid_misclass)

        print(f'Epoch[{epoch+1}/{config.epochs}], Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, Train F1: {train_f1:.2f}% | Valid Loss: {valid_loss:.4f}, Valid Acc: {valid_acc:.2f}%, Valid F1: {valid_f1:.2f}%, Valid Misclass: {valid_misclass:.2f}% | LR: {optimizer.state_dict()["param_groups"][0]["lr"]:.6f}')
        
        if valid_loss < best_val_loss:
            save_file = {
                "model": model.state_dict(),
                "optimizer": optimizer.state_dict(),
                "scheduler": scheduler.state_dict(),
                "epoch": epoch,
                "args": config
            }
            best_val_loss = valid_loss
            torch.save(save_file, "checkpointFiles/checkpointVGG.pth")
            besteps=epoch
            

        best_ckpt = torch.load("checkpointFiles/checkpointVGG.pth", map_location = config.device, weights_only = False)
        model.load_state_dict(best_ckpt["model"])
    
    printTrainresult(history,besteps)


if __name__ == "__main__":
    main()
# Out:
# Initializing model...
# Epoch[1/150], Train Loss: 1.0995, Train Acc: 31.25%, Train F1: 28.85% | Valid Loss: 1.0933, Valid Acc: 26.53%, Valid F1: 19.40%, Valid Misclass: 73.47% | LR: 0.000004
# Epoch[2/150], Train Loss: 1.0976, Train Acc: 33.93%, Train F1: 29.62% | Valid Loss: 1.0896, Valid Acc: 44.90%, Valid F1: 31.36%, Valid Misclass: 55.10% | LR: 0.000004
# Epoch[3/150], Train Loss: 1.0938, Train Acc: 33.04%, Train F1: 29.59% | Valid Loss: 1.0850, Valid Acc: 48.98%, Valid F1: 22.54%, Valid Misclass: 51.02% | LR: 0.000004
# Epoch[4/150], Train Loss: 1.0936, Train Acc: 33.93%, Train F1: 27.54% | Valid Loss: 1.0791, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000004
# Epoch[5/150], Train Loss: 1.0946, Train Acc: 37.50%, Train F1: 29.92% | Valid Loss: 1.0721, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000004
# Epoch[6/150], Train Loss: 1.0741, Train Acc: 48.21%, Train F1: 40.81% | Valid Loss: 1.0643, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000004
# Epoch[7/150], Train Loss: 1.0823, Train Acc: 39.29%, Train F1: 27.45% | Valid Loss: 1.0550, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000004
# Epoch[8/150], Train Loss: 1.0730, Train Acc: 43.75%, Train F1: 28.31% | Valid Loss: 1.0467, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000004
# Epoch[9/150], Train Loss: 1.0696, Train Acc: 48.21%, Train F1: 32.15% | Valid Loss: 1.0372, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000004
# Epoch[10/150], Train Loss: 1.0637, Train Acc: 50.89%, Train F1: 36.31% | Valid Loss: 1.0279, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000004
# Epoch[11/150], Train Loss: 1.0683, Train Acc: 46.43%, Train F1: 25.38% | Valid Loss: 1.0188, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000004
# Epoch[12/150], Train Loss: 1.0620, Train Acc: 46.43%, Train F1: 26.85% | Valid Loss: 1.0107, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000004
# Epoch[13/150], Train Loss: 1.0507, Train Acc: 47.32%, Train F1: 28.58% | Valid Loss: 1.0015, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000004
# Epoch[14/150], Train Loss: 1.0523, Train Acc: 43.75%, Train F1: 22.40% | Valid Loss: 0.9925, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000004
# Epoch[15/150], Train Loss: 1.0477, Train Acc: 43.75%, Train F1: 20.55% | Valid Loss: 0.9836, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000005
# Epoch[16/150], Train Loss: 1.0416, Train Acc: 46.43%, Train F1: 25.21% | Valid Loss: 0.9715, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000005
# Epoch[17/150], Train Loss: 1.0272, Train Acc: 46.43%, Train F1: 23.27% | Valid Loss: 0.9567, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000005
# Epoch[18/150], Train Loss: 1.0086, Train Acc: 45.54%, Train F1: 21.79% | Valid Loss: 0.9451, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000005
# Epoch[19/150], Train Loss: 1.0093, Train Acc: 47.32%, Train F1: 27.17% | Valid Loss: 0.9362, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000005
# Epoch[20/150], Train Loss: 0.9979, Train Acc: 47.32%, Train F1: 25.69% | Valid Loss: 0.9179, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000005
# Epoch[21/150], Train Loss: 0.9787, Train Acc: 49.11%, Train F1: 29.63% | Valid Loss: 0.9036, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000005
# Epoch[22/150], Train Loss: 0.9866, Train Acc: 49.11%, Train F1: 31.13% | Valid Loss: 0.8876, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000005
# Epoch[23/150], Train Loss: 0.9581, Train Acc: 54.46%, Train F1: 41.70% | Valid Loss: 0.8778, Valid Acc: 48.98%, Valid F1: 21.92%, Valid Misclass: 51.02% | LR: 0.000005
# Epoch[24/150], Train Loss: 0.9615, Train Acc: 52.68%, Train F1: 36.87% | Valid Loss: 0.8700, Valid Acc: 48.98%, Valid F1: 22.22%, Valid Misclass: 51.02% | LR: 0.000005
# Epoch[25/150], Train Loss: 0.9496, Train Acc: 50.00%, Train F1: 32.04% | Valid Loss: 0.8621, Valid Acc: 57.14%, Valid F1: 41.31%, Valid Misclass: 42.86% | LR: 0.000005
# Epoch[26/150], Train Loss: 0.9500, Train Acc: 51.79%, Train F1: 38.56% | Valid Loss: 0.8532, Valid Acc: 61.22%, Valid F1: 49.24%, Valid Misclass: 38.78% | LR: 0.000006
# Epoch[27/150], Train Loss: 0.9345, Train Acc: 54.46%, Train F1: 41.91% | Valid Loss: 0.8460, Valid Acc: 61.22%, Valid F1: 49.13%, Valid Misclass: 38.78% | LR: 0.000006
# Epoch[28/150], Train Loss: 0.9109, Train Acc: 64.29%, Train F1: 55.61% | Valid Loss: 0.8408, Valid Acc: 59.18%, Valid F1: 44.32%, Valid Misclass: 40.82% | LR: 0.000006
# Epoch[29/150], Train Loss: 0.9203, Train Acc: 60.71%, Train F1: 50.61% | Valid Loss: 0.8368, Valid Acc: 61.22%, Valid F1: 49.26%, Valid Misclass: 38.78% | LR: 0.000006
# Epoch[30/150], Train Loss: 0.8929, Train Acc: 66.96%, Train F1: 61.47% | Valid Loss: 0.8322, Valid Acc: 59.18%, Valid F1: 44.60%, Valid Misclass: 40.82% | LR: 0.000006
# Epoch[31/150], Train Loss: 0.9051, Train Acc: 61.61%, Train F1: 51.86% | Valid Loss: 0.8302, Valid Acc: 61.22%, Valid F1: 45.85%, Valid Misclass: 38.78% | LR: 0.000006
# Epoch[32/150], Train Loss: 0.8909, Train Acc: 60.71%, Train F1: 50.82% | Valid Loss: 0.8251, Valid Acc: 65.31%, Valid F1: 50.42%, Valid Misclass: 34.69% | LR: 0.000006
# Epoch[33/150], Train Loss: 0.8713, Train Acc: 74.11%, Train F1: 68.09% | Valid Loss: 0.8225, Valid Acc: 65.31%, Valid F1: 50.42%, Valid Misclass: 34.69% | LR: 0.000007
# Epoch[34/150], Train Loss: 0.8715, Train Acc: 66.07%, Train F1: 57.52% | Valid Loss: 0.8241, Valid Acc: 65.31%, Valid F1: 49.56%, Valid Misclass: 34.69% | LR: 0.000007
# Epoch[35/150], Train Loss: 0.8696, Train Acc: 67.86%, Train F1: 60.49% | Valid Loss: 0.8197, Valid Acc: 67.35%, Valid F1: 51.95%, Valid Misclass: 32.65% | LR: 0.000007
# Epoch[36/150], Train Loss: 0.8677, Train Acc: 69.64%, Train F1: 61.84% | Valid Loss: 0.8194, Valid Acc: 65.31%, Valid F1: 50.42%, Valid Misclass: 34.69% | LR: 0.000007
# Epoch[37/150], Train Loss: 0.8551, Train Acc: 72.32%, Train F1: 65.66% | Valid Loss: 0.8166, Valid Acc: 65.31%, Valid F1: 49.54%, Valid Misclass: 34.69% | LR: 0.000007
# Epoch[38/150], Train Loss: 0.8436, Train Acc: 74.11%, Train F1: 66.34% | Valid Loss: 0.8128, Valid Acc: 67.35%, Valid F1: 51.11%, Valid Misclass: 32.65% | LR: 0.000007
# Epoch[39/150], Train Loss: 0.8517, Train Acc: 66.07%, Train F1: 57.34% | Valid Loss: 0.8124, Valid Acc: 65.31%, Valid F1: 49.54%, Valid Misclass: 34.69% | LR: 0.000008
# Epoch[40/150], Train Loss: 0.8429, Train Acc: 67.86%, Train F1: 57.32% | Valid Loss: 0.8088, Valid Acc: 67.35%, Valid F1: 51.11%, Valid Misclass: 32.65% | LR: 0.000008
# Epoch[41/150], Train Loss: 0.8404, Train Acc: 69.64%, Train F1: 58.70% | Valid Loss: 0.8110, Valid Acc: 65.31%, Valid F1: 48.95%, Valid Misclass: 34.69% | LR: 0.000008
# Epoch[42/150], Train Loss: 0.8372, Train Acc: 69.64%, Train F1: 59.79% | Valid Loss: 0.8076, Valid Acc: 65.31%, Valid F1: 48.95%, Valid Misclass: 34.69% | LR: 0.000008
# Epoch[43/150], Train Loss: 0.8242, Train Acc: 75.00%, Train F1: 67.24% | Valid Loss: 0.8077, Valid Acc: 65.31%, Valid F1: 48.95%, Valid Misclass: 34.69% | LR: 0.000008
# Epoch[44/150], Train Loss: 0.8220, Train Acc: 74.11%, Train F1: 67.01% | Valid Loss: 0.8084, Valid Acc: 67.35%, Valid F1: 51.11%, Valid Misclass: 32.65% | LR: 0.000009
# Epoch[45/150], Train Loss: 0.8361, Train Acc: 66.96%, Train F1: 56.56% | Valid Loss: 0.8060, Valid Acc: 67.35%, Valid F1: 50.82%, Valid Misclass: 32.65% | LR: 0.000009
# Epoch[46/150], Train Loss: 0.8247, Train Acc: 68.75%, Train F1: 61.04% | Valid Loss: 0.8034, Valid Acc: 67.35%, Valid F1: 51.33%, Valid Misclass: 32.65% | LR: 0.000009
# Epoch[47/150], Train Loss: 0.8127, Train Acc: 73.21%, Train F1: 66.10% | Valid Loss: 0.8059, Valid Acc: 65.31%, Valid F1: 49.57%, Valid Misclass: 34.69% | LR: 0.000009
# Epoch[48/150], Train Loss: 0.8257, Train Acc: 70.54%, Train F1: 64.14% | Valid Loss: 0.8032, Valid Acc: 65.31%, Valid F1: 54.15%, Valid Misclass: 34.69% | LR: 0.000009
# Epoch[49/150], Train Loss: 0.8126, Train Acc: 74.11%, Train F1: 68.37% | Valid Loss: 0.8041, Valid Acc: 69.39%, Valid F1: 63.83%, Valid Misclass: 30.61% | LR: 0.000010
# Epoch[50/150], Train Loss: 0.8085, Train Acc: 75.00%, Train F1: 68.91% | Valid Loss: 0.8020, Valid Acc: 65.31%, Valid F1: 53.59%, Valid Misclass: 34.69% | LR: 0.000010
# Epoch[51/150], Train Loss: 0.7957, Train Acc: 74.11%, Train F1: 68.67% | Valid Loss: 0.8094, Valid Acc: 67.35%, Valid F1: 56.23%, Valid Misclass: 32.65% | LR: 0.000010
# Epoch[52/150], Train Loss: 0.8034, Train Acc: 75.89%, Train F1: 70.30% | Valid Loss: 0.8010, Valid Acc: 67.35%, Valid F1: 55.53%, Valid Misclass: 32.65% | LR: 0.000010
# Epoch[53/150], Train Loss: 0.8011, Train Acc: 74.11%, Train F1: 67.99% | Valid Loss: 0.8040, Valid Acc: 67.35%, Valid F1: 55.77%, Valid Misclass: 32.65% | LR: 0.000011
# Epoch[54/150], Train Loss: 0.7948, Train Acc: 75.00%, Train F1: 69.32% | Valid Loss: 0.8004, Valid Acc: 67.35%, Valid F1: 55.08%, Valid Misclass: 32.65% | LR: 0.000011
# Epoch[55/150], Train Loss: 0.8009, Train Acc: 73.21%, Train F1: 65.51% | Valid Loss: 0.8004, Valid Acc: 63.27%, Valid F1: 54.31%, Valid Misclass: 36.73% | LR: 0.000011
# Epoch[56/150], Train Loss: 0.7789, Train Acc: 77.68%, Train F1: 73.30% | Valid Loss: 0.7994, Valid Acc: 71.43%, Valid F1: 68.07%, Valid Misclass: 28.57% | LR: 0.000011
# Epoch[57/150], Train Loss: 0.7832, Train Acc: 76.79%, Train F1: 72.46% | Valid Loss: 0.7967, Valid Acc: 69.39%, Valid F1: 68.11%, Valid Misclass: 30.61% | LR: 0.000012
# Epoch[58/150], Train Loss: 0.7777, Train Acc: 81.25%, Train F1: 77.82% | Valid Loss: 0.8054, Valid Acc: 69.39%, Valid F1: 64.11%, Valid Misclass: 30.61% | LR: 0.000012
# Epoch[59/150], Train Loss: 0.7561, Train Acc: 78.57%, Train F1: 74.11% | Valid Loss: 0.8037, Valid Acc: 69.39%, Valid F1: 64.11%, Valid Misclass: 30.61% | LR: 0.000012
# Epoch[60/150], Train Loss: 0.7448, Train Acc: 83.93%, Train F1: 81.07% | Valid Loss: 0.7967, Valid Acc: 67.35%, Valid F1: 63.81%, Valid Misclass: 32.65% | LR: 0.000012
# Epoch[61/150], Train Loss: 0.7391, Train Acc: 84.82%, Train F1: 81.89% | Valid Loss: 0.8002, Valid Acc: 63.27%, Valid F1: 54.62%, Valid Misclass: 36.73% | LR: 0.000013
# Epoch[62/150], Train Loss: 0.7667, Train Acc: 77.68%, Train F1: 73.43% | Valid Loss: 0.7974, Valid Acc: 71.43%, Valid F1: 67.01%, Valid Misclass: 28.57% | LR: 0.000013
# Epoch[63/150], Train Loss: 0.7736, Train Acc: 77.68%, Train F1: 73.31% | Valid Loss: 0.7970, Valid Acc: 67.35%, Valid F1: 62.79%, Valid Misclass: 32.65% | LR: 0.000013
# Epoch[64/150], Train Loss: 0.7765, Train Acc: 76.79%, Train F1: 71.78% | Valid Loss: 0.7994, Valid Acc: 69.39%, Valid F1: 63.78%, Valid Misclass: 30.61% | LR: 0.000014
# Epoch[65/150], Train Loss: 0.7581, Train Acc: 83.04%, Train F1: 80.38% | Valid Loss: 0.7972, Valid Acc: 69.39%, Valid F1: 63.78%, Valid Misclass: 30.61% | LR: 0.000014
# Epoch[66/150], Train Loss: 0.7785, Train Acc: 75.00%, Train F1: 69.84% | Valid Loss: 0.7934, Valid Acc: 69.39%, Valid F1: 65.05%, Valid Misclass: 30.61% | LR: 0.000014
# Epoch[67/150], Train Loss: 0.7393, Train Acc: 85.71%, Train F1: 82.50% | Valid Loss: 0.7822, Valid Acc: 71.43%, Valid F1: 70.26%, Valid Misclass: 28.57% | LR: 0.000014
# Epoch[68/150], Train Loss: 0.7330, Train Acc: 84.82%, Train F1: 81.82% | Valid Loss: 0.7946, Valid Acc: 67.35%, Valid F1: 63.81%, Valid Misclass: 32.65% | LR: 0.000015
# Epoch[69/150], Train Loss: 0.7402, Train Acc: 83.93%, Train F1: 80.75% | Valid Loss: 0.7919, Valid Acc: 69.39%, Valid F1: 65.64%, Valid Misclass: 30.61% | LR: 0.000015
# Epoch[70/150], Train Loss: 0.7159, Train Acc: 86.61%, Train F1: 83.71% | Valid Loss: 0.7969, Valid Acc: 67.35%, Valid F1: 62.79%, Valid Misclass: 32.65% | LR: 0.000015
# Epoch[71/150], Train Loss: 0.7098, Train Acc: 85.71%, Train F1: 83.17% | Valid Loss: 0.8124, Valid Acc: 61.22%, Valid F1: 52.69%, Valid Misclass: 38.78% | LR: 0.000016
# Epoch[72/150], Train Loss: 0.7271, Train Acc: 84.82%, Train F1: 82.24% | Valid Loss: 0.8055, Valid Acc: 65.31%, Valid F1: 58.83%, Valid Misclass: 34.69% | LR: 0.000016
# Epoch[73/150], Train Loss: 0.7345, Train Acc: 84.82%, Train F1: 82.10% | Valid Loss: 0.8060, Valid Acc: 63.27%, Valid F1: 55.29%, Valid Misclass: 36.73% | LR: 0.000016
# Epoch[74/150], Train Loss: 0.7169, Train Acc: 85.71%, Train F1: 82.88% | Valid Loss: 0.8140, Valid Acc: 65.31%, Valid F1: 58.83%, Valid Misclass: 34.69% | LR: 0.000017
# Epoch[75/150], Train Loss: 0.7283, Train Acc: 85.71%, Train F1: 82.94% | Valid Loss: 0.8032, Valid Acc: 65.31%, Valid F1: 58.61%, Valid Misclass: 34.69% | LR: 0.000017
# Epoch[76/150], Train Loss: 0.7179, Train Acc: 87.50%, Train F1: 85.12% | Valid Loss: 0.8224, Valid Acc: 61.22%, Valid F1: 52.69%, Valid Misclass: 38.78% | LR: 0.000017
# Epoch[77/150], Train Loss: 0.6965, Train Acc: 91.07%, Train F1: 89.34% | Valid Loss: 0.8169, Valid Acc: 61.22%, Valid F1: 52.69%, Valid Misclass: 38.78% | LR: 0.000018
# Epoch[78/150], Train Loss: 0.6960, Train Acc: 88.39%, Train F1: 86.10% | Valid Loss: 0.8115, Valid Acc: 65.31%, Valid F1: 58.83%, Valid Misclass: 34.69% | LR: 0.000018
# Epoch[79/150], Train Loss: 0.7050, Train Acc: 88.39%, Train F1: 86.23% | Valid Loss: 0.7959, Valid Acc: 67.35%, Valid F1: 61.59%, Valid Misclass: 32.65% | LR: 0.000018
# Epoch[80/150], Train Loss: 0.7244, Train Acc: 83.93%, Train F1: 81.07% | Valid Loss: 0.7904, Valid Acc: 69.39%, Valid F1: 65.64%, Valid Misclass: 30.61% | LR: 0.000019
# Epoch[81/150], Train Loss: 0.7257, Train Acc: 85.71%, Train F1: 82.50% | Valid Loss: 0.7972, Valid Acc: 67.35%, Valid F1: 61.59%, Valid Misclass: 32.65% | LR: 0.000019
# Epoch[82/150], Train Loss: 0.7233, Train Acc: 83.04%, Train F1: 80.07% | Valid Loss: 0.8105, Valid Acc: 63.27%, Valid F1: 57.28%, Valid Misclass: 36.73% | LR: 0.000019
# Epoch[83/150], Train Loss: 0.7141, Train Acc: 87.50%, Train F1: 85.38% | Valid Loss: 0.7837, Valid Acc: 71.43%, Valid F1: 68.32%, Valid Misclass: 28.57% | LR: 0.000020
# Epoch[84/150], Train Loss: 0.7367, Train Acc: 84.82%, Train F1: 82.28% | Valid Loss: 0.8140, Valid Acc: 65.31%, Valid F1: 58.83%, Valid Misclass: 34.69% | LR: 0.000020
# Epoch[85/150], Train Loss: 0.7155, Train Acc: 84.82%, Train F1: 82.28% | Valid Loss: 0.8134, Valid Acc: 61.22%, Valid F1: 52.69%, Valid Misclass: 38.78% | LR: 0.000020
# Epoch[86/150], Train Loss: 0.7258, Train Acc: 86.61%, Train F1: 84.27% | Valid Loss: 0.8325, Valid Acc: 61.22%, Valid F1: 52.69%, Valid Misclass: 38.78% | LR: 0.000021
# Epoch[87/150], Train Loss: 0.7347, Train Acc: 82.14%, Train F1: 78.57% | Valid Loss: 0.7875, Valid Acc: 69.39%, Valid F1: 66.67%, Valid Misclass: 30.61% | LR: 0.000021
# Epoch[88/150], Train Loss: 0.7809, Train Acc: 75.00%, Train F1: 70.48% | Valid Loss: 0.8439, Valid Acc: 59.18%, Valid F1: 49.87%, Valid Misclass: 40.82% | LR: 0.000021
# Epoch[89/150], Train Loss: 0.7745, Train Acc: 78.57%, Train F1: 75.17% | Valid Loss: 0.7802, Valid Acc: 69.39%, Valid F1: 67.32%, Valid Misclass: 30.61% | LR: 0.000022
# Epoch[90/150], Train Loss: 0.7651, Train Acc: 79.46%, Train F1: 73.98% | Valid Loss: 0.8058, Valid Acc: 69.39%, Valid F1: 64.11%, Valid Misclass: 30.61% | LR: 0.000022
# Epoch[91/150], Train Loss: 0.7172, Train Acc: 87.50%, Train F1: 85.51% | Valid Loss: 0.7856, Valid Acc: 67.35%, Valid F1: 65.28%, Valid Misclass: 32.65% | LR: 0.000023
# Epoch[92/150], Train Loss: 0.6998, Train Acc: 88.39%, Train F1: 86.06% | Valid Loss: 0.8096, Valid Acc: 65.31%, Valid F1: 59.73%, Valid Misclass: 34.69% | LR: 0.000023
# Epoch[93/150], Train Loss: 0.6770, Train Acc: 92.86%, Train F1: 91.69% | Valid Loss: 0.8176, Valid Acc: 59.18%, Valid F1: 51.49%, Valid Misclass: 40.82% | LR: 0.000023
# Epoch[94/150], Train Loss: 0.6863, Train Acc: 92.86%, Train F1: 91.62% | Valid Loss: 0.8052, Valid Acc: 63.27%, Valid F1: 57.41%, Valid Misclass: 36.73% | LR: 0.000024
# Epoch[95/150], Train Loss: 0.7013, Train Acc: 87.50%, Train F1: 85.12% | Valid Loss: 0.7939, Valid Acc: 69.39%, Valid F1: 65.17%, Valid Misclass: 30.61% | LR: 0.000024
# Epoch[96/150], Train Loss: 0.7117, Train Acc: 86.61%, Train F1: 84.09% | Valid Loss: 0.7987, Valid Acc: 67.35%, Valid F1: 62.79%, Valid Misclass: 32.65% | LR: 0.000024
# Epoch[97/150], Train Loss: 0.6975, Train Acc: 87.50%, Train F1: 85.08% | Valid Loss: 0.8101, Valid Acc: 63.27%, Valid F1: 57.65%, Valid Misclass: 36.73% | LR: 0.000025
# Epoch[98/150], Train Loss: 0.6930, Train Acc: 87.50%, Train F1: 85.08% | Valid Loss: 0.8201, Valid Acc: 65.31%, Valid F1: 58.83%, Valid Misclass: 34.69% | LR: 0.000025
# Epoch[99/150], Train Loss: 0.7083, Train Acc: 83.93%, Train F1: 80.75% | Valid Loss: 0.7964, Valid Acc: 67.35%, Valid F1: 62.79%, Valid Misclass: 32.65% | LR: 0.000026
# Epoch[100/150], Train Loss: 0.7101, Train Acc: 86.61%, Train F1: 83.63% | Valid Loss: 0.8135, Valid Acc: 63.27%, Valid F1: 55.94%, Valid Misclass: 36.73% | LR: 0.000026
# Epoch[101/150], Train Loss: 0.6965, Train Acc: 88.39%, Train F1: 86.20% | Valid Loss: 0.8196, Valid Acc: 65.31%, Valid F1: 60.29%, Valid Misclass: 34.69% | LR: 0.000026
# Epoch[102/150], Train Loss: 0.7036, Train Acc: 86.61%, Train F1: 83.84% | Valid Loss: 0.8150, Valid Acc: 65.31%, Valid F1: 60.29%, Valid Misclass: 34.69% | LR: 0.000027
# Epoch[103/150], Train Loss: 0.7068, Train Acc: 88.39%, Train F1: 86.23% | Valid Loss: 0.7929, Valid Acc: 67.35%, Valid F1: 63.08%, Valid Misclass: 32.65% | LR: 0.000027
# Epoch[104/150], Train Loss: 0.7476, Train Acc: 76.79%, Train F1: 72.03% | Valid Loss: 0.7848, Valid Acc: 69.39%, Valid F1: 67.82%, Valid Misclass: 30.61% | LR: 0.000028
# Epoch[105/150], Train Loss: 0.7276, Train Acc: 84.82%, Train F1: 80.73% | Valid Loss: 0.8441, Valid Acc: 61.22%, Valid F1: 52.69%, Valid Misclass: 38.78% | LR: 0.000028
# Epoch[106/150], Train Loss: 0.7031, Train Acc: 84.82%, Train F1: 81.90% | Valid Loss: 0.7858, Valid Acc: 69.39%, Valid F1: 69.05%, Valid Misclass: 30.61% | LR: 0.000029
# Epoch[107/150], Train Loss: 0.7203, Train Acc: 84.82%, Train F1: 81.63% | Valid Loss: 0.8011, Valid Acc: 67.35%, Valid F1: 63.81%, Valid Misclass: 32.65% | LR: 0.000029
# Epoch[108/150], Train Loss: 0.6885, Train Acc: 89.29%, Train F1: 87.31% | Valid Loss: 0.7970, Valid Acc: 65.31%, Valid F1: 60.29%, Valid Misclass: 34.69% | LR: 0.000029
# Epoch[109/150], Train Loss: 0.7468, Train Acc: 81.25%, Train F1: 77.88% | Valid Loss: 0.8025, Valid Acc: 67.35%, Valid F1: 63.08%, Valid Misclass: 32.65% | LR: 0.000030
# Epoch[110/150], Train Loss: 0.7441, Train Acc: 80.36%, Train F1: 76.39% | Valid Loss: 0.8275, Valid Acc: 61.22%, Valid F1: 52.69%, Valid Misclass: 38.78% | LR: 0.000030
# Epoch[111/150], Train Loss: 0.7069, Train Acc: 88.39%, Train F1: 86.19% | Valid Loss: 0.8549, Valid Acc: 59.18%, Valid F1: 47.74%, Valid Misclass: 40.82% | LR: 0.000031
# Epoch[112/150], Train Loss: 0.6989, Train Acc: 88.39%, Train F1: 86.20% | Valid Loss: 0.8313, Valid Acc: 61.22%, Valid F1: 52.84%, Valid Misclass: 38.78% | LR: 0.000031
# Epoch[113/150], Train Loss: 0.6901, Train Acc: 90.18%, Train F1: 88.17% | Valid Loss: 0.8191, Valid Acc: 63.27%, Valid F1: 57.65%, Valid Misclass: 36.73% | LR: 0.000032
# Epoch[114/150], Train Loss: 0.7183, Train Acc: 83.04%, Train F1: 79.54% | Valid Loss: 0.8019, Valid Acc: 65.31%, Valid F1: 61.48%, Valid Misclass: 34.69% | LR: 0.000032
# Epoch[115/150], Train Loss: 0.7050, Train Acc: 87.50%, Train F1: 84.75% | Valid Loss: 0.8300, Valid Acc: 61.22%, Valid F1: 53.04%, Valid Misclass: 38.78% | LR: 0.000032
# Epoch[116/150], Train Loss: 0.6971, Train Acc: 87.50%, Train F1: 85.14% | Valid Loss: 0.7948, Valid Acc: 67.35%, Valid F1: 62.79%, Valid Misclass: 32.65% | LR: 0.000033
# Epoch[117/150], Train Loss: 0.7365, Train Acc: 80.36%, Train F1: 76.42% | Valid Loss: 0.8148, Valid Acc: 65.31%, Valid F1: 60.29%, Valid Misclass: 34.69% | LR: 0.000033
# Epoch[118/150], Train Loss: 0.7049, Train Acc: 86.61%, Train F1: 83.53% | Valid Loss: 0.8165, Valid Acc: 63.27%, Valid F1: 57.65%, Valid Misclass: 36.73% | LR: 0.000034
# Epoch[119/150], Train Loss: 0.7091, Train Acc: 86.61%, Train F1: 84.07% | Valid Loss: 0.7997, Valid Acc: 67.35%, Valid F1: 63.08%, Valid Misclass: 32.65% | LR: 0.000034
# Epoch[120/150], Train Loss: 0.6984, Train Acc: 86.61%, Train F1: 83.84% | Valid Loss: 0.8026, Valid Acc: 67.35%, Valid F1: 62.79%, Valid Misclass: 32.65% | LR: 0.000035
# Epoch[121/150], Train Loss: 0.7063, Train Acc: 87.50%, Train F1: 84.89% | Valid Loss: 0.7999, Valid Acc: 65.31%, Valid F1: 60.37%, Valid Misclass: 34.69% | LR: 0.000035
# Epoch[122/150], Train Loss: 0.7142, Train Acc: 83.93%, Train F1: 80.69% | Valid Loss: 0.7866, Valid Acc: 73.47%, Valid F1: 70.80%, Valid Misclass: 26.53% | LR: 0.000036
# Epoch[123/150], Train Loss: 0.7075, Train Acc: 87.50%, Train F1: 84.75% | Valid Loss: 0.8503, Valid Acc: 61.22%, Valid F1: 52.69%, Valid Misclass: 38.78% | LR: 0.000036
# Epoch[124/150], Train Loss: 0.7433, Train Acc: 81.25%, Train F1: 77.00% | Valid Loss: 0.7835, Valid Acc: 71.43%, Valid F1: 70.84%, Valid Misclass: 28.57% | LR: 0.000036
# Epoch[125/150], Train Loss: 0.7081, Train Acc: 87.50%, Train F1: 84.76% | Valid Loss: 0.8498, Valid Acc: 59.18%, Valid F1: 49.87%, Valid Misclass: 40.82% | LR: 0.000037
# Epoch[126/150], Train Loss: 0.7077, Train Acc: 86.61%, Train F1: 84.34% | Valid Loss: 0.7889, Valid Acc: 71.43%, Valid F1: 68.07%, Valid Misclass: 28.57% | LR: 0.000037
# Epoch[127/150], Train Loss: 0.6896, Train Acc: 89.29%, Train F1: 87.27% | Valid Loss: 0.8270, Valid Acc: 63.27%, Valid F1: 55.85%, Valid Misclass: 36.73% | LR: 0.000038
# Epoch[128/150], Train Loss: 0.6994, Train Acc: 86.61%, Train F1: 83.94% | Valid Loss: 0.7912, Valid Acc: 67.35%, Valid F1: 62.79%, Valid Misclass: 32.65% | LR: 0.000038
# Epoch[129/150], Train Loss: 0.7156, Train Acc: 84.82%, Train F1: 81.81% | Valid Loss: 0.7840, Valid Acc: 71.43%, Valid F1: 68.32%, Valid Misclass: 28.57% | LR: 0.000039
# Epoch[130/150], Train Loss: 0.7213, Train Acc: 85.71%, Train F1: 82.94% | Valid Loss: 0.7868, Valid Acc: 71.43%, Valid F1: 70.76%, Valid Misclass: 28.57% | LR: 0.000039
# Epoch[131/150], Train Loss: 0.7285, Train Acc: 83.04%, Train F1: 79.01% | Valid Loss: 0.7811, Valid Acc: 71.43%, Valid F1: 68.32%, Valid Misclass: 28.57% | LR: 0.000040
# Epoch[132/150], Train Loss: 0.7650, Train Acc: 79.46%, Train F1: 75.54% | Valid Loss: 0.8530, Valid Acc: 57.14%, Valid F1: 46.30%, Valid Misclass: 42.86% | LR: 0.000040
# Epoch[133/150], Train Loss: 0.7049, Train Acc: 86.61%, Train F1: 83.27% | Valid Loss: 0.8113, Valid Acc: 63.27%, Valid F1: 55.94%, Valid Misclass: 36.73% | LR: 0.000041
# Epoch[134/150], Train Loss: 0.7413, Train Acc: 85.71%, Train F1: 82.88% | Valid Loss: 0.7928, Valid Acc: 67.35%, Valid F1: 63.81%, Valid Misclass: 32.65% | LR: 0.000041
# Epoch[135/150], Train Loss: 0.7195, Train Acc: 88.39%, Train F1: 86.12% | Valid Loss: 0.8315, Valid Acc: 71.43%, Valid F1: 71.20%, Valid Misclass: 28.57% | LR: 0.000042
# Epoch[136/150], Train Loss: 0.7314, Train Acc: 81.25%, Train F1: 78.02% | Valid Loss: 0.7894, Valid Acc: 65.31%, Valid F1: 63.25%, Valid Misclass: 34.69% | LR: 0.000042
# Epoch[137/150], Train Loss: 0.7513, Train Acc: 80.36%, Train F1: 76.63% | Valid Loss: 0.8530, Valid Acc: 55.10%, Valid F1: 43.58%, Valid Misclass: 44.90% | LR: 0.000042
# Epoch[138/150], Train Loss: 0.7180, Train Acc: 86.61%, Train F1: 83.53% | Valid Loss: 0.7962, Valid Acc: 67.35%, Valid F1: 62.79%, Valid Misclass: 32.65% | LR: 0.000043
# Epoch[139/150], Train Loss: 0.7234, Train Acc: 83.93%, Train F1: 80.75% | Valid Loss: 0.7779, Valid Acc: 71.43%, Valid F1: 69.35%, Valid Misclass: 28.57% | LR: 0.000043
# Epoch[140/150], Train Loss: 0.6681, Train Acc: 92.86%, Train F1: 91.62% | Valid Loss: 0.7783, Valid Acc: 71.43%, Valid F1: 70.13%, Valid Misclass: 28.57% | LR: 0.000044
# Epoch[141/150], Train Loss: 0.6731, Train Acc: 90.18%, Train F1: 88.41% | Valid Loss: 0.7796, Valid Acc: 71.43%, Valid F1: 69.76%, Valid Misclass: 28.57% | LR: 0.000044
# Epoch[142/150], Train Loss: 0.7131, Train Acc: 83.04%, Train F1: 78.89% | Valid Loss: 1.0677, Valid Acc: 61.22%, Valid F1: 61.27%, Valid Misclass: 38.78% | LR: 0.000045
# Epoch[143/150], Train Loss: 0.7522, Train Acc: 82.14%, Train F1: 79.64% | Valid Loss: 0.9161, Valid Acc: 51.02%, Valid F1: 27.11%, Valid Misclass: 48.98% | LR: 0.000045
# Epoch[144/150], Train Loss: 0.7202, Train Acc: 85.71%, Train F1: 84.24% | Valid Loss: 0.9137, Valid Acc: 65.31%, Valid F1: 64.70%, Valid Misclass: 34.69% | LR: 0.000046
# Epoch[145/150], Train Loss: 0.6775, Train Acc: 89.29%, Train F1: 87.15% | Valid Loss: 0.7664, Valid Acc: 71.43%, Valid F1: 67.69%, Valid Misclass: 28.57% | LR: 0.000046
# Epoch[146/150], Train Loss: 0.6676, Train Acc: 90.18%, Train F1: 88.39% | Valid Loss: 0.7834, Valid Acc: 67.35%, Valid F1: 60.43%, Valid Misclass: 32.65% | LR: 0.000047
# Epoch[147/150], Train Loss: 0.6332, Train Acc: 93.75%, Train F1: 92.62% | Valid Loss: 0.7981, Valid Acc: 65.31%, Valid F1: 58.83%, Valid Misclass: 34.69% | LR: 0.000047
# Epoch[148/150], Train Loss: 0.6469, Train Acc: 91.96%, Train F1: 90.77% | Valid Loss: 0.7666, Valid Acc: 71.43%, Valid F1: 70.13%, Valid Misclass: 28.57% | LR: 0.000048
# Epoch[149/150], Train Loss: 0.6437, Train Acc: 91.07%, Train F1: 89.53% | Valid Loss: 0.7695, Valid Acc: 73.47%, Valid F1: 72.36%, Valid Misclass: 26.53% | LR: 0.000048
# Epoch[150/150], Train Loss: 0.6380, Train Acc: 95.54%, Train F1: 94.92% | Valid Loss: 0.8093, Valid Acc: 65.31%, Valid F1: 58.83%, Valid Misclass: 34.69% | LR: 0.000049
# BatchSize:  16  / LR:  0.0001  / WeightDecay:  0.001  / Seed:  18
# Best result: Epoch145,
# Train Loss: 0.6775, Train Acc: 89.29%, Train F1: 87.15% |
# Valid Loss: 0.7664, Valid Acc: 71.43%, Valid F1: 67.69%, Valid Misclass: 28.57%

# %% [markdown]
# ## testing

# %%
def testing(model, test_loader, device):
    model.eval()
    preds = []
    with torch.no_grad(): 
        for image, age, gender in test_loader:
            image = image.to(device = device, dtype = torch.float)
            age = age.to(device)
            gender = gender.to(device)
            logits = model(image, age, gender)
            pred = torch.argmax(logits, dim = 1)
            preds.append(pred)

    preds = torch.cat(preds)
    
    # TODO_8: 因為輸出的 preds為 0,1,2，所以請調整成 1,2,3。
    preds = preds + 1
    
    return preds
    
seed_everything(config.seed)
test_data = pd.read_csv(os.path.join(config.root, 'test.csv'))

# TODO_9: 填寫 test_dataset、test_loader、model 四個空格，記得 test_loader 的 shuffle = False。

# Creating the test dataset using the ParkinsonsDataset class
test_dataset1 = ParkinsonsDataset(test_data, mode="test", transforms=build_transform(is_train=False))
# Creating the test dataset using the ParkinsonsDataset class
test_dataset2 = ParkinsonsDataset(test_data, mode="test", transforms=build_transform_ViT(is_train=False))

# DataLoader for the test dataset (shuffle is set to False)
test_loader1 = torch.utils.data.DataLoader(test_dataset1, batch_size=config.batch_size, shuffle=False)
test_loader2 = torch.utils.data.DataLoader(test_dataset2, batch_size=config.batch_size, shuffle=False)

# %%
# TODO_10: 將 .csv 取名。

# Initialize the model (VGGplus in this case, could be ResNetplus if you switch)
model = VGGplus(num_classes=config.num_classes, features_grad=True)

best_ckpt = torch.load(f"checkpointFiles/checkpointVGG.pth", map_location=config.device)
model.load_state_dict(best_ckpt["model"])


model.to(config.device)

preds = testing(model, test_loader1, config.device)

# Create a DataFrame with predictions
submission_df = pd.DataFrame()  # Start with an empty DataFrame
submission_df['ID'] = test_data['ID']
# Add the 'Stage' column with predictions
submission_df['Stage'] = preds.cpu().numpy()  # Convert preds from GPU to CPU and then to NumPy

# Specify the path for the submission file
submission_file_path = os.path.join(config.root, 'submissionVGG.csv')  # Ensure this points to the desired directory

# Save the DataFrame to a CSV file
submission_df.to_csv(submission_file_path, index=False, header=True)  # Save without index and with header

print(f"Predictions saved to {submission_file_path}.")  # Print confirmation message
# Out:
# Predictions saved to ./hwk02_data\submissionVGG.csv.
